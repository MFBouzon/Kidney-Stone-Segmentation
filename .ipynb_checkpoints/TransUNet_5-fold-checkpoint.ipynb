# %%
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
import os
import csv
import random
import numpy as np

import time
 
from tqdm import tqdm 

from PIL import Image
import cv2
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import KFold

from tensorflow.keras import backend as K
# Out:
# 2025-03-23 23:15:26.604241: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-23 23:15:26.604286: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-23 23:15:26.610423: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-23 23:15:26.660398: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-23 23:15:27.523654: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
num_classes = 1
k = 5


IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

DATA_PATH = 'data/'

data_ids = next(os.walk(DATA_PATH+'/image'))[2]

X = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
y = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.float32)

# Definição do diretório de saída
output_dir = "Trans UNet DICE 5-fold model"
os.makedirs(output_dir, exist_ok=True)  # Garante que a pasta existe

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_GPU_ALLOCATOR']= 'cuda_malloc_async'

# %%
print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(data_ids), total=len(data_ids)):   
    path = DATA_PATH
    img = imread(path + '/image/' + id_)[:,:]
    img = img.reshape(img.shape[0], img.shape[1], IMG_CHANNELS)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X[n] = img  #Fill empty X_train with values from img
    
    mask = imread(path + 'label/' + id_)
    mask = (mask >= 250)
    mask = np.expand_dims(resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                      preserve_range=True), axis=-1)
    y[n] = mask 
    #plt.axis("off")
    #imshow(y[n])
    #plt.show()
# Out:
# Resizing training images and masks
# 100%|█████████████████████████████████████████████████████████████████████████████████| 838/838 [00:30<00:00, 27.89it/s]

# %%
@tf.keras.utils.register_keras_serializable()
def f1_score(y_true, y_pred):
    """Calcula o F1-Score para segmentação binária"""
    y_pred = K.round(y_pred)  # Arredondar para 0 ou 1
    tp = K.sum(K.cast(y_true * y_pred, 'float32'))  # Verdadeiros Positivos
    fp = K.sum(K.cast((1 - y_true) * y_pred, 'float32'))  # Falsos Positivos
    fn = K.sum(K.cast(y_true * (1 - y_pred), 'float32'))  # Falsos Negativos
    
    precision = tp / (tp + fp + K.epsilon())  # Precision
    recall = tp / (tp + fn + K.epsilon())  # Recall
    
    f1 = 2 * (precision * recall) / (precision + recall + K.epsilon())  # F1-Score
    return f1

# %%
@tf.keras.utils.register_keras_serializable()
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))

# %%
from tensorflow.keras.layers import (
    Conv2D, Dropout, BatchNormalization, ReLU, MaxPooling2D,
    Conv2DTranspose, Concatenate, Reshape, Dense, LayerNormalization,
    MultiHeadAttention, Input
)
from tensorflow.keras.models import Model

class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, num_patches, d_model):
        super(PositionalEmbedding, self).__init__()
        self.pos_emb = self.add_weight(
            shape=(1, num_patches, d_model),
            initializer='zeros',
            trainable=True,
            name='positional_embedding'
        )

    def call(self, inputs):
        return inputs + self.pos_emb

def trans_unet():
    input_shape =  (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
    inputs = Input(input_shape)
    
    def conv_block(x, filters, dropout=0.1):
        x = Conv2D(filters, (3, 3), activation='relu', 
                 kernel_initializer='he_normal', padding='same')(x)
        x = Dropout(dropout)(x)
        x = Conv2D(filters, (3, 3), activation='relu', 
                 kernel_initializer='he_normal', padding='same')(x)
        x = BatchNormalization()(x)
        return ReLU()(x)
    
    # Encoder (CNN)
    c1 = conv_block(inputs, 16)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = conv_block(p1, 32)
    p2 = MaxPooling2D((2, 2))(c2)
    
    c3 = conv_block(p2, 64, dropout=0.2)
    p3 = MaxPooling2D((2, 2))(c3)
    
    c4 = conv_block(p3, 128, dropout=0.2)
    p4 = MaxPooling2D((2, 2))(c4)
    
    # Transformer Bottleneck
    h = input_shape[0] // 16
    w = input_shape[1] // 16
    num_patches = h * w
    d_model = 256
    
    x = Reshape((num_patches, 128))(p4)
    x = Dense(d_model)(x)
    x = PositionalEmbedding(num_patches, d_model)(x)
    
    # Transformer Encoder
    num_heads = 8
    for _ in range(4):
        x1 = LayerNormalization()(x)
        attn = MultiHeadAttention(num_heads=num_heads, key_dim=d_model//num_heads)(x1, x1)
        x = attn + x
        x2 = LayerNormalization()(x)
        mlp = Dense(d_model * 4, activation='gelu')(x2)
        mlp = Dense(d_model)(mlp)
        x = mlp + x
    
    x = Reshape((h, w, d_model))(x)
    
    # Decoder (UNet++ style)
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
    u6 = Concatenate()([u6, c4])
    c6 = conv_block(u6, 128)
    
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = Concatenate()([u7, c3])
    c7 = conv_block(u7, 64)
    
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = Concatenate()([u8, c2])
    c8 = conv_block(u8, 32)
    
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = Concatenate()([u9, c1])
    c9 = conv_block(u9, 16)
    
    outputs = Conv2D(num_classes, (1, 1), activation='sigmoid')(c9)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss=dice_loss, metrics=[
        'accuracy', 
        tf.keras.metrics.Recall(name='recall'), 
        tf.keras.metrics.Precision(name='precision'),
        f1_score,
        tf.keras.metrics.IoU(num_classes=2, target_class_ids={0,1}, name='IoU')
    ])
    
    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

# Dicionário para armazenar métricas por fold
fold_metrics_summary = []

kf = KFold(n_splits=k, shuffle=True, random_state=28)
fold = 5

for i, (train_ind, test_ind) in enumerate(kf.split(X)):
    if i < (fold-1):
        continue
    
    
    print("Fold: " + str(fold))
    X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]

    model = trans_unet()
    
    
    checkpoint_filepath = os.path.join(output_dir, f'model_{fold}fold.keras')
    callbacks = [
            tf.keras.callbacks.TensorBoard(log_dir='logs'),
            tf.keras.callbacks.ModelCheckpoint(
                filepath=checkpoint_filepath,
                save_weights_only=False,
                monitor='val_f1_score',
                mode='max',
                save_best_only=True,
                verbose=1)]
    
    start_time = time.time()
    model.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=16, epochs=150, callbacks=callbacks)
    end_time = time.time()
    training_time = end_time - start_time

     # Salvando o tempo de treinamento
    with open(os.path.join(output_dir, 'training_time.txt'), 'a') as f:
        f.write(f'Fold {fold}: {training_time:.2f} segundos\n')
    print(f"O modelo demorou {training_time:.2f} segundos para treinar.")
    
    loss = model.history.history['loss']
    val_loss = model.history.history['val_loss']
    
    with open(os.path.join(output_dir, f'loss_fold{fold}.csv'), 'w', newline='') as csvfile:
        writer = csv.writer(csvfile, delimiter=';')
        writer.writerow(["Epoch", "Loss", "Validation Loss"])
        for epoch, (l, vl) in enumerate(zip(loss, val_loss), start=1):
            writer.writerow([epoch, l, vl])
            
     # Plotando e salvando a figura
    plt.figure()
    plt.plot(loss, 'r', label='Training loss')
    plt.plot(val_loss, 'g', label='Validation loss')
    plt.title(f'Training and Validation Loss - Fold {fold}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss Value')
    plt.ylim([0, 1])
    plt.legend()
    plt.savefig(os.path.join(output_dir, f'loss_plot_fold{fold}.png'))
    plt.close()


    fold_metrics = []

    acc_fold = []
    jacc_fold = []
    f1_fold = []
    prec_fold = []
    rec_fold = []
    
    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc_score = accuracy_score(sample_mask, predicted_mask)
        jacc_score = jaccard_score(sample_mask, predicted_mask)
        f1_score_val = f1_score(sample_mask, predicted_mask).numpy()
        prec_score = precision_score(sample_mask, predicted_mask)
        rec_score = recall_score(sample_mask, predicted_mask)

        acc_fold.append(acc_score)
        jacc_fold.append(jacc_score)
        f1_fold.append(f1_score_val)
        prec_fold.append(prec_score)
        rec_fold.append(rec_score)

        fold_metrics.append([i, acc_score, jacc_score, f1_score_val, prec_score, rec_score])
        
    # Salvando métricas por imagem
    with open(os.path.join(output_dir, f'metrics_fold{fold}.csv'), 'w', newline='') as csvfile:
        writer = csv.writer(csvfile, delimiter=';')
        writer.writerow(["Index", "Accuracy", "Jaccard", "DICE", "Precision", "Recall"])
        writer.writerows(fold_metrics)

    # Salvando a média do fold para cada métrica
    fold_metrics_summary.append([
        fold, np.mean(acc_fold), np.std(acc_fold),
        np.mean(jacc_fold), np.std(jacc_fold),
        np.mean(f1_fold), np.std(f1_fold),
        np.mean(prec_fold), np.std(prec_fold),
        np.mean(rec_fold), np.std(rec_fold)
    ])

        
    del model 

    tf.keras.backend.clear_session()

    fold+=1
    
# Calculando médias gerais
acc_total = [m[1] for m in fold_metrics_summary]
jacc_total = [m[3] for m in fold_metrics_summary]
f1_total = [m[5] for m in fold_metrics_summary]
prec_total = [m[7] for m in fold_metrics_summary]
rec_total = [m[9] for m in fold_metrics_summary]

general_summary = [
    ["Fold", "Accuracy Mean", "Accuracy Std", "Jaccard Mean", "Jaccard Std",
     "DICE Mean", "DICE Std", "Precision Mean", "Precision Std", "Recall Mean", "Recall Std"]
]

general_summary.extend(fold_metrics_summary)

general_summary.append([
    "Overall Mean", np.mean(acc_total), np.std(acc_total),
    np.mean(jacc_total), np.std(jacc_total),
    np.mean(f1_total), np.std(f1_total),
    np.mean(prec_total), np.std(prec_total),
    np.mean(rec_total), np.std(rec_total)
])

# Salvando o resumo das métricas por fold e geral
with open(os.path.join(output_dir, 'metrics_summary.csv'), 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=';')
    writer.writerows(general_summary)

print("Métricas salvas com sucesso na pasta:", output_dir)
# Out:
# Fold: 3
# 2025-03-23 23:16:00.081828: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.120793: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.120838: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.122604: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.122638: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.122652: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.266527: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.266591: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.266597: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-03-23 23:16:00.266607: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-03-23 23:16:00.266612: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2025-03-23 23:16:00.266768: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-23 23:16:00.266789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/150
# 2025-03-23 23:16:06.711720: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-03-23 23:16:07.530904: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-03-23 23:16:12.084434: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:306] gpu_async_0 cuMemAllocAsync failed to allocate 1828790272 bytes: CUDA error: out of memory (CUDA_ERROR_OUT_OF_MEMORY)
#  Reported by CUDA: Free memory/Total memory: 383131624/12878086144
# 2025-03-23 23:16:12.084473: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:311] Stats: Limit:                     10022289408
# InUse:                     10530479014
# MaxInUse:                  11352581046
# NumAllocs:                        1627
# MaxAllocSize:               2722250752
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-03-23 23:16:12.084499: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:63] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2025-03-23 23:16:12.084502: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 1, 22
# 2025-03-23 23:16:12.084504: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 4, 57
# 2025-03-23 23:16:12.084505: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 8, 9
# 2025-03-23 23:16:12.084507: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 16, 2
# 2025-03-23 23:16:12.084508: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 64, 36
# 2025-03-23 23:16:12.084509: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 128, 35
# 2025-03-23 23:16:12.084511: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 256, 35
# 2025-03-23 23:16:12.084512: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 512, 35
# 2025-03-23 23:16:12.084513: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 576, 3
# 2025-03-23 23:16:12.084515: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 1024, 111
# 2025-03-23 23:16:12.084516: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 1028, 1
# 2025-03-23 23:16:12.084518: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 4096, 12
# 2025-03-23 23:16:12.084519: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 8192, 3
# 2025-03-23 23:16:12.084520: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 9216, 6
# 2025-03-23 23:16:12.084522: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 18432, 7
# 2025-03-23 23:16:12.084523: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 32768, 3
# 2025-03-23 23:16:12.084524: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 36864, 6
# 2025-03-23 23:16:12.084526: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 65536, 24
# 2025-03-23 23:16:12.084527: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 73728, 6
# 2025-03-23 23:16:12.084528: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 131072, 6
# 2025-03-23 23:16:12.084530: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 147456, 6
# 2025-03-23 23:16:12.084531: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 262144, 48
# 2025-03-23 23:16:12.084533: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 294912, 6
# 2025-03-23 23:16:12.084534: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 524288, 3
# 2025-03-23 23:16:12.084535: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 589824, 6
# 2025-03-23 23:16:12.084537: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 1048576, 27
# 2025-03-23 23:16:12.084538: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 1179648, 3
# 2025-03-23 23:16:12.084539: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 4194304, 2
# 2025-03-23 23:16:12.084541: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 8388608, 3
# 2025-03-23 23:16:12.084542: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 16777216, 47
# 2025-03-23 23:16:12.084544: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 33554432, 11
# 2025-03-23 23:16:12.084545: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 67108864, 27
# 2025-03-23 23:16:12.084546: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 134217728, 9
# 2025-03-23 23:16:12.084548: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 175636480, 1
# 2025-03-23 23:16:12.084549: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 268435456, 7
# 2025-03-23 23:16:12.084550: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 285212672, 1
# 2025-03-23 23:16:12.084552: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 536870912, 6
# 2025-03-23 23:16:12.084553: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 702545920, 1
# 2025-03-23 23:16:12.084557: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:97] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 11106516992
# 2025-03-23 23:16:12.084559: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:99] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 10530479014
# 2025-03-23 23:16:12.084560: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:100] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 12952010752
# 2025-03-23 23:16:12.084562: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:101] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 11352581046
# 2025-03-23 23:16:13.050787: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f8bc4530a80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-03-23 23:16:13.050823: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2025-03-23 23:16:13.055808: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742782573.125085  881072 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 [==============================] - ETA: 0s - loss: 0.9973 - accuracy: 0.7734 - recall: 0.9599 - precision: 0.0027 - f1_score: 0.0078 - IoU: 0.5081
# Epoch 1: val_f1_score improved from -inf to 0.00327, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 104s 1s/step - loss: 0.9973 - accuracy: 0.7734 - recall: 0.9599 - precision: 0.0027 - f1_score: 0.0078 - IoU: 0.5081 - val_loss: 0.9968 - val_accuracy: 0.6381 - val_recall: 0.9999 - val_precision: 0.0017 - val_f1_score: 0.0033 - val_IoU: 0.4014
# Epoch 2/150
# 42/42 [==============================] - ETA: 0s - loss: 0.9949 - accuracy: 0.9811 - recall: 0.9931 - precision: 0.0320 - f1_score: 0.0671 - IoU: 0.5476
# Epoch 2: val_f1_score did not improve from 0.00327
# 42/42 [==============================] - 49s 1s/step - loss: 0.9949 - accuracy: 0.9811 - recall: 0.9931 - precision: 0.0320 - f1_score: 0.0671 - IoU: 0.5476 - val_loss: 0.9992 - val_accuracy: 0.9994 - val_recall: 2.1840e-04 - val_precision: 1.0000 - val_f1_score: 0.0014 - val_IoU: 0.4997
# Epoch 3/150
# 42/42 [==============================] - ETA: 0s - loss: 0.9909 - accuracy: 0.9904 - recall: 0.9836 - precision: 0.0605 - f1_score: 0.1239 - IoU: 0.5898
# Epoch 3: val_f1_score did not improve from 0.00327
# 42/42 [==============================] - 38s 906ms/step - loss: 0.9909 - accuracy: 0.9904 - recall: 0.9836 - precision: 0.0605 - f1_score: 0.1239 - IoU: 0.5898 - val_loss: 0.9987 - val_accuracy: 0.9994 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_IoU: 0.4997
# Epoch 4/150
# 42/42 [==============================] - ETA: 0s - loss: 0.9812 - accuracy: 0.9944 - recall: 0.9731 - precision: 0.0989 - f1_score: 0.2203 - IoU: 0.6249
# Epoch 4: val_f1_score did not improve from 0.00327
# 42/42 [==============================] - 40s 945ms/step - loss: 0.9812 - accuracy: 0.9944 - recall: 0.9731 - precision: 0.0989 - f1_score: 0.2203 - IoU: 0.6249 - val_loss: 0.9993 - val_accuracy: 0.9994 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_IoU: 0.4997
# Epoch 5/150
# 42/42 [==============================] - ETA: 0s - loss: 0.9517 - accuracy: 0.9983 - recall: 0.9624 - precision: 0.2701 - f1_score: 0.4411 - IoU: 0.7080
# Epoch 5: val_f1_score did not improve from 0.00327
# 42/42 [==============================] - 32s 766ms/step - loss: 0.9517 - accuracy: 0.9983 - recall: 0.9624 - precision: 0.2701 - f1_score: 0.4411 - IoU: 0.7080 - val_loss: 0.9986 - val_accuracy: 0.1003 - val_recall: 0.9927 - val_precision: 6.8783e-04 - val_f1_score: 0.0013 - val_IoU: 0.4997
# Epoch 6/150
# 42/42 [==============================] - ETA: 0s - loss: 0.8422 - accuracy: 0.9994 - recall: 0.9567 - precision: 0.5158 - f1_score: 0.6766 - IoU: 0.8163
# Epoch 6: val_f1_score did not improve from 0.00327
# 42/42 [==============================] - 29s 691ms/step - loss: 0.8422 - accuracy: 0.9994 - recall: 0.9567 - precision: 0.5158 - f1_score: 0.6766 - IoU: 0.8163 - val_loss: 0.9998 - val_accuracy: 0.9994 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_IoU: 0.4997
# Epoch 7/150
# 42/42 [==============================] - ETA: 0s - loss: 0.5824 - accuracy: 0.9997 - recall: 0.9121 - precision: 0.6937 - f1_score: 0.7922 - IoU: 0.8429
# Epoch 7: val_f1_score did not improve from 0.00327
# 42/42 [==============================] - 31s 741ms/step - loss: 0.5824 - accuracy: 0.9997 - recall: 0.9121 - precision: 0.6937 - f1_score: 0.7922 - IoU: 0.8429 - val_loss: 0.9997 - val_accuracy: 0.9994 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - val_IoU: 0.4997
# Epoch 8/150
# 42/42 [==============================] - ETA: 0s - loss: 0.3094 - accuracy: 0.9998 - recall: 0.8942 - precision: 0.8521 - f1_score: 0.8677 - IoU: 0.8736
# Epoch 8: val_f1_score improved from 0.00327 to 0.03959, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 29s 697ms/step - loss: 0.3094 - accuracy: 0.9998 - recall: 0.8942 - precision: 0.8521 - f1_score: 0.8677 - IoU: 0.8736 - val_loss: 0.9601 - val_accuracy: 0.9994 - val_recall: 0.0258 - val_precision: 0.7030 - val_f1_score: 0.0396 - val_IoU: 0.5079
# Epoch 9/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9999 - recall: 0.9222 - precision: 0.9069 - f1_score: 0.9136 - IoU: 0.9011
# Epoch 9: val_f1_score improved from 0.03959 to 0.85975, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 37s 878ms/step - loss: 0.1696 - accuracy: 0.9999 - recall: 0.9222 - precision: 0.9069 - f1_score: 0.9136 - IoU: 0.9011 - val_loss: 0.1875 - val_accuracy: 0.9999 - val_recall: 0.9214 - val_precision: 0.8653 - val_f1_score: 0.8598 - val_IoU: 0.9072
# Epoch 10/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9999 - recall: 0.9278 - precision: 0.9287 - f1_score: 0.9222 - IoU: 0.9094
# Epoch 10: val_f1_score did not improve from 0.85975
# 42/42 [==============================] - 35s 832ms/step - loss: 0.1287 - accuracy: 0.9999 - recall: 0.9278 - precision: 0.9287 - f1_score: 0.9222 - IoU: 0.9094 - val_loss: 0.3628 - val_accuracy: 0.9998 - val_recall: 0.6893 - val_precision: 0.9794 - val_f1_score: 0.6685 - val_IoU: 0.7621
# Epoch 11/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9999 - recall: 0.9397 - precision: 0.9408 - f1_score: 0.9381 - IoU: 0.9210
# Epoch 11: val_f1_score improved from 0.85975 to 0.92284, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 31s 732ms/step - loss: 0.0958 - accuracy: 0.9999 - recall: 0.9397 - precision: 0.9408 - f1_score: 0.9381 - IoU: 0.9210 - val_loss: 0.1303 - val_accuracy: 0.9999 - val_recall: 0.8928 - val_precision: 0.9833 - val_f1_score: 0.9228 - val_IoU: 0.8650
# Epoch 12/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0843 - accuracy: 0.9999 - recall: 0.9414 - precision: 0.9453 - f1_score: 0.9419 - IoU: 0.9238
# Epoch 12: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 31s 751ms/step - loss: 0.0843 - accuracy: 0.9999 - recall: 0.9414 - precision: 0.9453 - f1_score: 0.9419 - IoU: 0.9238 - val_loss: 0.2745 - val_accuracy: 0.9997 - val_recall: 0.5716 - val_precision: 0.9937 - val_f1_score: 0.7742 - val_IoU: 0.6920
# Epoch 13/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1253 - accuracy: 0.9999 - recall: 0.8991 - precision: 0.9007 - f1_score: 0.8945 - IoU: 0.8923
# Epoch 13: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 31s 738ms/step - loss: 0.1253 - accuracy: 0.9999 - recall: 0.8991 - precision: 0.9007 - f1_score: 0.8945 - IoU: 0.8923 - val_loss: 0.7285 - val_accuracy: 0.9995 - val_recall: 0.1615 - val_precision: 0.9897 - val_f1_score: 0.3115 - val_IoU: 0.5527
# Epoch 14/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9999 - recall: 0.8732 - precision: 0.8897 - f1_score: 0.8808 - IoU: 0.8659
# Epoch 14: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 32s 754ms/step - loss: 0.1363 - accuracy: 0.9999 - recall: 0.8732 - precision: 0.8897 - f1_score: 0.8808 - IoU: 0.8659 - val_loss: 0.9770 - val_accuracy: 0.9994 - val_recall: 0.0082 - val_precision: 0.8561 - val_f1_score: 0.0252 - val_IoU: 0.5021
# Epoch 15/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9999 - recall: 0.8977 - precision: 0.9171 - f1_score: 0.9064 - IoU: 0.8780
# Epoch 15: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 35s 844ms/step - loss: 0.1085 - accuracy: 0.9999 - recall: 0.8977 - precision: 0.9171 - f1_score: 0.9064 - IoU: 0.8780 - val_loss: 0.1624 - val_accuracy: 0.9998 - val_recall: 0.7586 - val_precision: 0.9700 - val_f1_score: 0.8663 - val_IoU: 0.7556
# Epoch 16/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9999 - recall: 0.9358 - precision: 0.9350 - f1_score: 0.9326 - IoU: 0.9080
# Epoch 16: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 43s 1s/step - loss: 0.0797 - accuracy: 0.9999 - recall: 0.9358 - precision: 0.9350 - f1_score: 0.9326 - IoU: 0.9080 - val_loss: 0.1128 - val_accuracy: 0.9999 - val_recall: 0.8780 - val_precision: 0.9715 - val_f1_score: 0.9074 - val_IoU: 0.8661
# Epoch 17/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0697 - accuracy: 0.9999 - recall: 0.9374 - precision: 0.9476 - f1_score: 0.9411 - IoU: 0.9147
# Epoch 17: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 35s 827ms/step - loss: 0.0697 - accuracy: 0.9999 - recall: 0.9374 - precision: 0.9476 - f1_score: 0.9411 - IoU: 0.9147 - val_loss: 0.1637 - val_accuracy: 0.9998 - val_recall: 0.7486 - val_precision: 0.9577 - val_f1_score: 0.8642 - val_IoU: 0.7663
# Epoch 18/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9999 - recall: 0.9470 - precision: 0.9453 - f1_score: 0.9432 - IoU: 0.9221
# Epoch 18: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 32s 762ms/step - loss: 0.0660 - accuracy: 0.9999 - recall: 0.9470 - precision: 0.9453 - f1_score: 0.9432 - IoU: 0.9221 - val_loss: 0.1400 - val_accuracy: 0.9998 - val_recall: 0.7191 - val_precision: 0.9854 - val_f1_score: 0.8785 - val_IoU: 0.7626
# Epoch 19/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9999 - recall: 0.9219 - precision: 0.9365 - f1_score: 0.9278 - IoU: 0.9133
# Epoch 19: val_f1_score did not improve from 0.92284
# 42/42 [==============================] - 80s 2s/step - loss: 0.0805 - accuracy: 0.9999 - recall: 0.9219 - precision: 0.9365 - f1_score: 0.9278 - IoU: 0.9133 - val_loss: 0.2749 - val_accuracy: 0.9997 - val_recall: 0.5286 - val_precision: 0.9450 - val_f1_score: 0.7481 - val_IoU: 0.7038
# Epoch 20/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9999 - recall: 0.9434 - precision: 0.9495 - f1_score: 0.9448 - IoU: 0.9268
# Epoch 20: val_f1_score improved from 0.92284 to 0.92900, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 33s 792ms/step - loss: 0.0627 - accuracy: 0.9999 - recall: 0.9434 - precision: 0.9495 - f1_score: 0.9448 - IoU: 0.9268 - val_loss: 0.0793 - val_accuracy: 0.9999 - val_recall: 0.8570 - val_precision: 0.9866 - val_f1_score: 0.9290 - val_IoU: 0.8365
# Epoch 21/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9999 - recall: 0.9511 - precision: 0.9550 - f1_score: 0.9521 - IoU: 0.9325
# Epoch 21: val_f1_score did not improve from 0.92900
# 42/42 [==============================] - 34s 809ms/step - loss: 0.0546 - accuracy: 0.9999 - recall: 0.9511 - precision: 0.9550 - f1_score: 0.9521 - IoU: 0.9325 - val_loss: 0.0796 - val_accuracy: 0.9999 - val_recall: 0.8628 - val_precision: 0.9601 - val_f1_score: 0.9268 - val_IoU: 0.8625
# Epoch 22/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9999 - recall: 0.9575 - precision: 0.9529 - f1_score: 0.9534 - IoU: 0.9369
# Epoch 22: val_f1_score did not improve from 0.92900
# 42/42 [==============================] - 37s 878ms/step - loss: 0.0524 - accuracy: 0.9999 - recall: 0.9575 - precision: 0.9529 - f1_score: 0.9534 - IoU: 0.9369 - val_loss: 0.1386 - val_accuracy: 0.9998 - val_recall: 0.7348 - val_precision: 0.9656 - val_f1_score: 0.8754 - val_IoU: 0.7956
# Epoch 23/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9999 - recall: 0.9521 - precision: 0.9591 - f1_score: 0.9546 - IoU: 0.9346
# Epoch 23: val_f1_score did not improve from 0.92900
# 42/42 [==============================] - 40s 966ms/step - loss: 0.0508 - accuracy: 0.9999 - recall: 0.9521 - precision: 0.9591 - f1_score: 0.9546 - IoU: 0.9346 - val_loss: 0.1313 - val_accuracy: 0.9998 - val_recall: 0.7224 - val_precision: 0.9751 - val_f1_score: 0.8803 - val_IoU: 0.7962
# Epoch 24/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0467 - accuracy: 0.9999 - recall: 0.9619 - precision: 0.9567 - f1_score: 0.9581 - IoU: 0.9417
# Epoch 24: val_f1_score did not improve from 0.92900
# 42/42 [==============================] - 42s 996ms/step - loss: 0.0467 - accuracy: 0.9999 - recall: 0.9619 - precision: 0.9567 - f1_score: 0.9581 - IoU: 0.9417 - val_loss: 0.0836 - val_accuracy: 0.9999 - val_recall: 0.8137 - val_precision: 0.9840 - val_f1_score: 0.9246 - val_IoU: 0.8436
# Epoch 25/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9999 - recall: 0.9524 - precision: 0.9588 - f1_score: 0.9542 - IoU: 0.9346
# Epoch 25: val_f1_score improved from 0.92900 to 0.93515, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 141s 3s/step - loss: 0.0505 - accuracy: 0.9999 - recall: 0.9524 - precision: 0.9588 - f1_score: 0.9542 - IoU: 0.9346 - val_loss: 0.0766 - val_accuracy: 0.9999 - val_recall: 0.8938 - val_precision: 0.9867 - val_f1_score: 0.9351 - val_IoU: 0.8825
# Epoch 26/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9999 - recall: 0.9498 - precision: 0.9500 - f1_score: 0.9477 - IoU: 0.9329
# Epoch 26: val_f1_score improved from 0.93515 to 0.94290, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 75s 2s/step - loss: 0.0563 - accuracy: 0.9999 - recall: 0.9498 - precision: 0.9500 - f1_score: 0.9477 - IoU: 0.9329 - val_loss: 0.0684 - val_accuracy: 0.9999 - val_recall: 0.8640 - val_precision: 0.9844 - val_f1_score: 0.9429 - val_IoU: 0.8665
# Epoch 27/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9999 - recall: 0.9497 - precision: 0.9545 - f1_score: 0.9492 - IoU: 0.9363
# Epoch 27: val_f1_score did not improve from 0.94290
# 42/42 [==============================] - 45s 1s/step - loss: 0.0548 - accuracy: 0.9999 - recall: 0.9497 - precision: 0.9545 - f1_score: 0.9492 - IoU: 0.9363 - val_loss: 0.0821 - val_accuracy: 0.9999 - val_recall: 0.8282 - val_precision: 0.9814 - val_f1_score: 0.9222 - val_IoU: 0.8501
# Epoch 28/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9999 - recall: 0.9523 - precision: 0.9562 - f1_score: 0.9531 - IoU: 0.9394
# Epoch 28: val_f1_score improved from 0.94290 to 0.94819, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 29s 698ms/step - loss: 0.0508 - accuracy: 0.9999 - recall: 0.9523 - precision: 0.9562 - f1_score: 0.9531 - IoU: 0.9394 - val_loss: 0.0567 - val_accuracy: 0.9999 - val_recall: 0.9253 - val_precision: 0.9783 - val_f1_score: 0.9482 - val_IoU: 0.9200
# Epoch 29/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9999 - recall: 0.9578 - precision: 0.9540 - f1_score: 0.9549 - IoU: 0.9439
# Epoch 29: val_f1_score did not improve from 0.94819
# 42/42 [==============================] - 32s 764ms/step - loss: 0.0487 - accuracy: 0.9999 - recall: 0.9578 - precision: 0.9540 - f1_score: 0.9549 - IoU: 0.9439 - val_loss: 0.0722 - val_accuracy: 0.9999 - val_recall: 0.8690 - val_precision: 0.9885 - val_f1_score: 0.9438 - val_IoU: 0.8819
# Epoch 30/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9999 - recall: 0.9565 - precision: 0.9619 - f1_score: 0.9580 - IoU: 0.9435
# Epoch 30: val_f1_score improved from 0.94819 to 0.95145, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 30s 726ms/step - loss: 0.0452 - accuracy: 0.9999 - recall: 0.9565 - precision: 0.9619 - f1_score: 0.9580 - IoU: 0.9435 - val_loss: 0.0512 - val_accuracy: 0.9999 - val_recall: 0.9155 - val_precision: 0.9678 - val_f1_score: 0.9515 - val_IoU: 0.9154
# Epoch 31/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9999 - recall: 0.9590 - precision: 0.9594 - f1_score: 0.9575 - IoU: 0.9450
# Epoch 31: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 43s 1s/step - loss: 0.0456 - accuracy: 0.9999 - recall: 0.9590 - precision: 0.9594 - f1_score: 0.9575 - IoU: 0.9450 - val_loss: 0.0556 - val_accuracy: 0.9999 - val_recall: 0.8926 - val_precision: 0.9782 - val_f1_score: 0.9499 - val_IoU: 0.8948
# Epoch 32/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 1.0000 - recall: 0.9605 - precision: 0.9622 - f1_score: 0.9604 - IoU: 0.9461
# Epoch 32: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 44s 1s/step - loss: 0.0424 - accuracy: 1.0000 - recall: 0.9605 - precision: 0.9622 - f1_score: 0.9604 - IoU: 0.9461 - val_loss: 0.0692 - val_accuracy: 0.9999 - val_recall: 0.8402 - val_precision: 0.9858 - val_f1_score: 0.9363 - val_IoU: 0.8631
# Epoch 33/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 1.0000 - recall: 0.9581 - precision: 0.9627 - f1_score: 0.9605 - IoU: 0.9445
# Epoch 33: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 67s 2s/step - loss: 0.0422 - accuracy: 1.0000 - recall: 0.9581 - precision: 0.9627 - f1_score: 0.9605 - IoU: 0.9445 - val_loss: 0.0608 - val_accuracy: 0.9999 - val_recall: 0.8705 - val_precision: 0.9864 - val_f1_score: 0.9449 - val_IoU: 0.8868
# Epoch 34/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9999 - recall: 0.9563 - precision: 0.9507 - f1_score: 0.9531 - IoU: 0.9398
# Epoch 34: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 39s 934ms/step - loss: 0.0493 - accuracy: 0.9999 - recall: 0.9563 - precision: 0.9507 - f1_score: 0.9531 - IoU: 0.9398 - val_loss: 0.2046 - val_accuracy: 0.9998 - val_recall: 0.8429 - val_precision: 0.8085 - val_f1_score: 0.8024 - val_IoU: 0.8261
# Epoch 35/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9999 - recall: 0.9451 - precision: 0.9519 - f1_score: 0.9474 - IoU: 0.9343
# Epoch 35: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 41s 914ms/step - loss: 0.0551 - accuracy: 0.9999 - recall: 0.9451 - precision: 0.9519 - f1_score: 0.9474 - IoU: 0.9343 - val_loss: 0.0839 - val_accuracy: 0.9999 - val_recall: 0.8772 - val_precision: 0.9810 - val_f1_score: 0.9209 - val_IoU: 0.8897
# Epoch 36/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9999 - recall: 0.9535 - precision: 0.9536 - f1_score: 0.9509 - IoU: 0.9397
# Epoch 36: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 43s 1s/step - loss: 0.0516 - accuracy: 0.9999 - recall: 0.9535 - precision: 0.9536 - f1_score: 0.9509 - IoU: 0.9397 - val_loss: 0.1441 - val_accuracy: 0.9999 - val_recall: 0.8394 - val_precision: 0.9942 - val_f1_score: 0.8914 - val_IoU: 0.8784
# Epoch 37/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9999 - recall: 0.9498 - precision: 0.9596 - f1_score: 0.9546 - IoU: 0.9415
# Epoch 37: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 42s 1s/step - loss: 0.0476 - accuracy: 0.9999 - recall: 0.9498 - precision: 0.9596 - f1_score: 0.9546 - IoU: 0.9415 - val_loss: 0.1024 - val_accuracy: 0.9998 - val_recall: 0.7492 - val_precision: 0.9784 - val_f1_score: 0.9026 - val_IoU: 0.8295
# Epoch 38/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 1.0000 - recall: 0.9592 - precision: 0.9632 - f1_score: 0.9612 - IoU: 0.9466
# Epoch 38: val_f1_score did not improve from 0.95145
# 42/42 [==============================] - 35s 844ms/step - loss: 0.0408 - accuracy: 1.0000 - recall: 0.9592 - precision: 0.9632 - f1_score: 0.9612 - IoU: 0.9466 - val_loss: 0.0522 - val_accuracy: 1.0000 - val_recall: 0.9772 - val_precision: 0.9454 - val_f1_score: 0.9426 - val_IoU: 0.9568
# Epoch 39/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 1.0000 - recall: 0.9593 - precision: 0.9639 - f1_score: 0.9606 - IoU: 0.9462
# Epoch 39: val_f1_score improved from 0.95145 to 0.96539, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 36s 867ms/step - loss: 0.0409 - accuracy: 1.0000 - recall: 0.9593 - precision: 0.9639 - f1_score: 0.9606 - IoU: 0.9462 - val_loss: 0.0349 - val_accuracy: 1.0000 - val_recall: 0.9664 - val_precision: 0.9698 - val_f1_score: 0.9654 - val_IoU: 0.9523
# Epoch 40/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9999 - recall: 0.9562 - precision: 0.9591 - f1_score: 0.9566 - IoU: 0.9449
# Epoch 40: val_f1_score did not improve from 0.96539
# 42/42 [==============================] - 31s 729ms/step - loss: 0.0453 - accuracy: 0.9999 - recall: 0.9562 - precision: 0.9591 - f1_score: 0.9566 - IoU: 0.9449 - val_loss: 0.0548 - val_accuracy: 0.9999 - val_recall: 0.8734 - val_precision: 0.9794 - val_f1_score: 0.9478 - val_IoU: 0.8938
# Epoch 41/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 1.0000 - recall: 0.9649 - precision: 0.9619 - f1_score: 0.9626 - IoU: 0.9520
# Epoch 41: val_f1_score improved from 0.96539 to 0.96759, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 29s 695ms/step - loss: 0.0391 - accuracy: 1.0000 - recall: 0.9649 - precision: 0.9619 - f1_score: 0.9626 - IoU: 0.9520 - val_loss: 0.0360 - val_accuracy: 1.0000 - val_recall: 0.9433 - val_precision: 0.9816 - val_f1_score: 0.9676 - val_IoU: 0.9349
# Epoch 42/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 1.0000 - recall: 0.9633 - precision: 0.9631 - f1_score: 0.9620 - IoU: 0.9503
# Epoch 42: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 27s 647ms/step - loss: 0.0397 - accuracy: 1.0000 - recall: 0.9633 - precision: 0.9631 - f1_score: 0.9620 - IoU: 0.9503 - val_loss: 0.0668 - val_accuracy: 0.9999 - val_recall: 0.8523 - val_precision: 0.9913 - val_f1_score: 0.9368 - val_IoU: 0.8791
# Epoch 43/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 1.0000 - recall: 0.9621 - precision: 0.9666 - f1_score: 0.9637 - IoU: 0.9498
# Epoch 43: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 27s 640ms/step - loss: 0.0380 - accuracy: 1.0000 - recall: 0.9621 - precision: 0.9666 - f1_score: 0.9637 - IoU: 0.9498 - val_loss: 0.0363 - val_accuracy: 0.9999 - val_recall: 0.9323 - val_precision: 0.9828 - val_f1_score: 0.9650 - val_IoU: 0.9318
# Epoch 44/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 1.0000 - recall: 0.9644 - precision: 0.9639 - f1_score: 0.9617 - IoU: 0.9518
# Epoch 44: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 30s 730ms/step - loss: 0.0398 - accuracy: 1.0000 - recall: 0.9644 - precision: 0.9639 - f1_score: 0.9617 - IoU: 0.9518 - val_loss: 0.0464 - val_accuracy: 0.9999 - val_recall: 0.8943 - val_precision: 0.9834 - val_f1_score: 0.9565 - val_IoU: 0.9119
# Epoch 45/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 1.0000 - recall: 0.9639 - precision: 0.9661 - f1_score: 0.9647 - IoU: 0.9521
# Epoch 45: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 32s 768ms/step - loss: 0.0367 - accuracy: 1.0000 - recall: 0.9639 - precision: 0.9661 - f1_score: 0.9647 - IoU: 0.9521 - val_loss: 0.0496 - val_accuracy: 0.9999 - val_recall: 0.8818 - val_precision: 0.9836 - val_f1_score: 0.9523 - val_IoU: 0.9042
# Epoch 46/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 1.0000 - recall: 0.9605 - precision: 0.9667 - f1_score: 0.9625 - IoU: 0.9505
# Epoch 46: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 34s 826ms/step - loss: 0.0390 - accuracy: 1.0000 - recall: 0.9605 - precision: 0.9667 - f1_score: 0.9625 - IoU: 0.9505 - val_loss: 0.0467 - val_accuracy: 0.9999 - val_recall: 0.9285 - val_precision: 0.9586 - val_f1_score: 0.9540 - val_IoU: 0.9313
# Epoch 47/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 1.0000 - recall: 0.9631 - precision: 0.9628 - f1_score: 0.9625 - IoU: 0.9518
# Epoch 47: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 36s 853ms/step - loss: 0.0388 - accuracy: 1.0000 - recall: 0.9631 - precision: 0.9628 - f1_score: 0.9625 - IoU: 0.9518 - val_loss: 0.0376 - val_accuracy: 0.9999 - val_recall: 0.9493 - val_precision: 0.9665 - val_f1_score: 0.9628 - val_IoU: 0.9422
# Epoch 48/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0376 - accuracy: 1.0000 - recall: 0.9644 - precision: 0.9641 - f1_score: 0.9637 - IoU: 0.9529
# Epoch 48: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 35s 835ms/step - loss: 0.0376 - accuracy: 1.0000 - recall: 0.9644 - precision: 0.9641 - f1_score: 0.9637 - IoU: 0.9529 - val_loss: 0.0813 - val_accuracy: 0.9999 - val_recall: 0.9660 - val_precision: 0.9273 - val_f1_score: 0.9218 - val_IoU: 0.9391
# Epoch 49/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0378 - accuracy: 1.0000 - recall: 0.9649 - precision: 0.9627 - f1_score: 0.9634 - IoU: 0.9534
# Epoch 49: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 29s 688ms/step - loss: 0.0378 - accuracy: 1.0000 - recall: 0.9649 - precision: 0.9627 - f1_score: 0.9634 - IoU: 0.9534 - val_loss: 0.0574 - val_accuracy: 1.0000 - val_recall: 0.9779 - val_precision: 0.9480 - val_f1_score: 0.9445 - val_IoU: 0.9560
# Epoch 50/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 1.0000 - recall: 0.9655 - precision: 0.9633 - f1_score: 0.9636 - IoU: 0.9541
# Epoch 50: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 30s 723ms/step - loss: 0.0377 - accuracy: 1.0000 - recall: 0.9655 - precision: 0.9633 - f1_score: 0.9636 - IoU: 0.9541 - val_loss: 0.0880 - val_accuracy: 0.9999 - val_recall: 0.9716 - val_precision: 0.9038 - val_f1_score: 0.9013 - val_IoU: 0.9353
# Epoch 51/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 0.9999 - recall: 0.9370 - precision: 0.9070 - f1_score: 0.9179 - IoU: 0.9181
# Epoch 51: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 33s 780ms/step - loss: 0.0834 - accuracy: 0.9999 - recall: 0.9370 - precision: 0.9070 - f1_score: 0.9179 - IoU: 0.9181 - val_loss: 0.3283 - val_accuracy: 0.9997 - val_recall: 0.4835 - val_precision: 0.9868 - val_f1_score: 0.6696 - val_IoU: 0.7079
# Epoch 52/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9999 - recall: 0.9219 - precision: 0.9485 - f1_score: 0.9307 - IoU: 0.9266
# Epoch 52: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 33s 775ms/step - loss: 0.0707 - accuracy: 0.9999 - recall: 0.9219 - precision: 0.9485 - f1_score: 0.9307 - IoU: 0.9266 - val_loss: 0.1062 - val_accuracy: 0.9999 - val_recall: 0.9020 - val_precision: 0.9671 - val_f1_score: 0.9057 - val_IoU: 0.9218
# Epoch 53/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9999 - recall: 0.9582 - precision: 0.9596 - f1_score: 0.9583 - IoU: 0.9477
# Epoch 53: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 45s 1s/step - loss: 0.0428 - accuracy: 0.9999 - recall: 0.9582 - precision: 0.9596 - f1_score: 0.9583 - IoU: 0.9477 - val_loss: 0.0572 - val_accuracy: 0.9999 - val_recall: 0.9530 - val_precision: 0.9601 - val_f1_score: 0.9450 - val_IoU: 0.9422
# Epoch 54/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9999 - recall: 0.9550 - precision: 0.9612 - f1_score: 0.9564 - IoU: 0.9459
# Epoch 54: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 42s 1s/step - loss: 0.0446 - accuracy: 0.9999 - recall: 0.9550 - precision: 0.9612 - f1_score: 0.9564 - IoU: 0.9459 - val_loss: 0.0581 - val_accuracy: 0.9999 - val_recall: 0.8820 - val_precision: 0.9854 - val_f1_score: 0.9445 - val_IoU: 0.9084
# Epoch 55/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 1.0000 - recall: 0.9615 - precision: 0.9627 - f1_score: 0.9605 - IoU: 0.9522
# Epoch 55: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 29s 691ms/step - loss: 0.0405 - accuracy: 1.0000 - recall: 0.9615 - precision: 0.9627 - f1_score: 0.9605 - IoU: 0.9522 - val_loss: 0.0486 - val_accuracy: 0.9999 - val_recall: 0.9170 - val_precision: 0.9911 - val_f1_score: 0.9550 - val_IoU: 0.9295
# Epoch 56/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 1.0000 - recall: 0.9603 - precision: 0.9620 - f1_score: 0.9611 - IoU: 0.9522
# Epoch 56: val_f1_score did not improve from 0.96759
# 42/42 [==============================] - 33s 791ms/step - loss: 0.0398 - accuracy: 1.0000 - recall: 0.9603 - precision: 0.9620 - f1_score: 0.9611 - IoU: 0.9522 - val_loss: 0.0738 - val_accuracy: 0.9999 - val_recall: 0.8400 - val_precision: 0.9945 - val_f1_score: 0.9329 - val_IoU: 0.8720
# Epoch 57/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 1.0000 - recall: 0.9623 - precision: 0.9650 - f1_score: 0.9614 - IoU: 0.9537
# Epoch 57: val_f1_score improved from 0.96759 to 0.97079, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 37s 897ms/step - loss: 0.0396 - accuracy: 1.0000 - recall: 0.9623 - precision: 0.9650 - f1_score: 0.9614 - IoU: 0.9537 - val_loss: 0.0294 - val_accuracy: 1.0000 - val_recall: 0.9704 - val_precision: 0.9746 - val_f1_score: 0.9708 - val_IoU: 0.9614
# Epoch 58/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 1.0000 - recall: 0.9668 - precision: 0.9654 - f1_score: 0.9655 - IoU: 0.9569
# Epoch 58: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 55s 1s/step - loss: 0.0355 - accuracy: 1.0000 - recall: 0.9668 - precision: 0.9654 - f1_score: 0.9655 - IoU: 0.9569 - val_loss: 0.0310 - val_accuracy: 1.0000 - val_recall: 0.9646 - val_precision: 0.9759 - val_f1_score: 0.9697 - val_IoU: 0.9559
# Epoch 59/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 1.0000 - recall: 0.9672 - precision: 0.9650 - f1_score: 0.9642 - IoU: 0.9576
# Epoch 59: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 30s 726ms/step - loss: 0.0367 - accuracy: 1.0000 - recall: 0.9672 - precision: 0.9650 - f1_score: 0.9642 - IoU: 0.9576 - val_loss: 0.0333 - val_accuracy: 1.0000 - val_recall: 0.9436 - val_precision: 0.9816 - val_f1_score: 0.9677 - val_IoU: 0.9418
# Epoch 60/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 1.0000 - recall: 0.9674 - precision: 0.9658 - f1_score: 0.9662 - IoU: 0.9569
# Epoch 60: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 34s 826ms/step - loss: 0.0346 - accuracy: 1.0000 - recall: 0.9674 - precision: 0.9658 - f1_score: 0.9662 - IoU: 0.9569 - val_loss: 0.0360 - val_accuracy: 0.9999 - val_recall: 0.9320 - val_precision: 0.9846 - val_f1_score: 0.9655 - val_IoU: 0.9352
# Epoch 61/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 1.0000 - recall: 0.9643 - precision: 0.9646 - f1_score: 0.9633 - IoU: 0.9557
# Epoch 61: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 31s 744ms/step - loss: 0.0374 - accuracy: 1.0000 - recall: 0.9643 - precision: 0.9646 - f1_score: 0.9633 - IoU: 0.9557 - val_loss: 0.0404 - val_accuracy: 0.9999 - val_recall: 0.9115 - val_precision: 0.9900 - val_f1_score: 0.9611 - val_IoU: 0.9229
# Epoch 62/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 1.0000 - recall: 0.9645 - precision: 0.9677 - f1_score: 0.9649 - IoU: 0.9563
# Epoch 62: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 30s 715ms/step - loss: 0.0358 - accuracy: 1.0000 - recall: 0.9645 - precision: 0.9677 - f1_score: 0.9649 - IoU: 0.9563 - val_loss: 0.0510 - val_accuracy: 0.9999 - val_recall: 0.8701 - val_precision: 0.9889 - val_f1_score: 0.9509 - val_IoU: 0.9023
# Epoch 63/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 1.0000 - recall: 0.9662 - precision: 0.9665 - f1_score: 0.9654 - IoU: 0.9557
# Epoch 63: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 30s 706ms/step - loss: 0.0355 - accuracy: 1.0000 - recall: 0.9662 - precision: 0.9665 - f1_score: 0.9654 - IoU: 0.9557 - val_loss: 0.0404 - val_accuracy: 0.9999 - val_recall: 0.9357 - val_precision: 0.9714 - val_f1_score: 0.9588 - val_IoU: 0.9357
# Epoch 64/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 1.0000 - recall: 0.9680 - precision: 0.9658 - f1_score: 0.9652 - IoU: 0.9572
# Epoch 64: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 30s 708ms/step - loss: 0.0357 - accuracy: 1.0000 - recall: 0.9680 - precision: 0.9658 - f1_score: 0.9652 - IoU: 0.9572 - val_loss: 0.0333 - val_accuracy: 1.0000 - val_recall: 0.9909 - val_precision: 0.9528 - val_f1_score: 0.9666 - val_IoU: 0.9760
# Epoch 65/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 1.0000 - recall: 0.9663 - precision: 0.9639 - f1_score: 0.9641 - IoU: 0.9558
# Epoch 65: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 31s 737ms/step - loss: 0.0368 - accuracy: 1.0000 - recall: 0.9663 - precision: 0.9639 - f1_score: 0.9641 - IoU: 0.9558 - val_loss: 0.0378 - val_accuracy: 0.9999 - val_recall: 0.9384 - val_precision: 0.9737 - val_f1_score: 0.9634 - val_IoU: 0.9411
# Epoch 66/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 1.0000 - recall: 0.9696 - precision: 0.9652 - f1_score: 0.9659 - IoU: 0.9582
# Epoch 66: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 44s 1s/step - loss: 0.0349 - accuracy: 1.0000 - recall: 0.9696 - precision: 0.9652 - f1_score: 0.9659 - IoU: 0.9582 - val_loss: 0.0340 - val_accuracy: 0.9999 - val_recall: 0.9319 - val_precision: 0.9849 - val_f1_score: 0.9670 - val_IoU: 0.9354
# Epoch 67/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 1.0000 - recall: 0.9656 - precision: 0.9677 - f1_score: 0.9656 - IoU: 0.9561
# Epoch 67: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 46s 1s/step - loss: 0.0351 - accuracy: 1.0000 - recall: 0.9656 - precision: 0.9677 - f1_score: 0.9656 - IoU: 0.9561 - val_loss: 0.0458 - val_accuracy: 0.9999 - val_recall: 0.8946 - val_precision: 0.9894 - val_f1_score: 0.9559 - val_IoU: 0.9146
# Epoch 68/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 1.0000 - recall: 0.9670 - precision: 0.9674 - f1_score: 0.9657 - IoU: 0.9568
# Epoch 68: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 43s 1s/step - loss: 0.0350 - accuracy: 1.0000 - recall: 0.9670 - precision: 0.9674 - f1_score: 0.9657 - IoU: 0.9568 - val_loss: 0.0381 - val_accuracy: 0.9999 - val_recall: 0.9298 - val_precision: 0.9872 - val_f1_score: 0.9645 - val_IoU: 0.9347
# Epoch 69/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 1.0000 - recall: 0.9656 - precision: 0.9696 - f1_score: 0.9667 - IoU: 0.9566
# Epoch 69: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 38s 906ms/step - loss: 0.0341 - accuracy: 1.0000 - recall: 0.9656 - precision: 0.9696 - f1_score: 0.9667 - IoU: 0.9566 - val_loss: 0.0584 - val_accuracy: 0.9999 - val_recall: 0.8480 - val_precision: 0.9868 - val_f1_score: 0.9439 - val_IoU: 0.8866
# Epoch 70/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 1.0000 - recall: 0.9703 - precision: 0.9665 - f1_score: 0.9675 - IoU: 0.9600
# Epoch 70: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 32s 750ms/step - loss: 0.0331 - accuracy: 1.0000 - recall: 0.9703 - precision: 0.9665 - f1_score: 0.9675 - IoU: 0.9600 - val_loss: 0.0391 - val_accuracy: 0.9999 - val_recall: 0.9235 - val_precision: 0.9893 - val_f1_score: 0.9647 - val_IoU: 0.9312
# Epoch 71/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0340 - accuracy: 1.0000 - recall: 0.9672 - precision: 0.9673 - f1_score: 0.9665 - IoU: 0.9581
# Epoch 71: val_f1_score did not improve from 0.97079
# 42/42 [==============================] - 38s 906ms/step - loss: 0.0340 - accuracy: 1.0000 - recall: 0.9672 - precision: 0.9673 - f1_score: 0.9665 - IoU: 0.9581 - val_loss: 0.0363 - val_accuracy: 0.9999 - val_recall: 0.9324 - val_precision: 0.9836 - val_f1_score: 0.9658 - val_IoU: 0.9353
# Epoch 72/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 1.0000 - recall: 0.9708 - precision: 0.9679 - f1_score: 0.9682 - IoU: 0.9590
# Epoch 72: val_f1_score improved from 0.97079 to 0.97133, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# 42/42 [==============================] - 41s 980ms/step - loss: 0.0325 - accuracy: 1.0000 - recall: 0.9708 - precision: 0.9679 - f1_score: 0.9682 - IoU: 0.9590 - val_loss: 0.0296 - val_accuracy: 1.0000 - val_recall: 0.9471 - val_precision: 0.9877 - val_f1_score: 0.9713 - val_IoU: 0.9439
# Epoch 73/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0343 - accuracy: 1.0000 - recall: 0.9685 - precision: 0.9691 - f1_score: 0.9663 - IoU: 0.9595
# Epoch 73: val_f1_score improved from 0.97133 to 0.97369, saving model to Trans UNet DICE 5-fold model/model_3fold.keras
# ...
# 2025-03-24 02:41:54.450413: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 9216, 18
# 2025-03-24 02:41:54.450415: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 18432, 19
# 2025-03-24 02:41:54.450416: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 32768, 9
# 2025-03-24 02:41:54.450418: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 36864, 18
# 2025-03-24 02:41:54.450419: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 65536, 24
# 2025-03-24 02:41:54.450420: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 73728, 18
# 2025-03-24 02:41:54.450422: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 131072, 18
# 2025-03-24 02:41:54.450423: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 147456, 18
# 2025-03-24 02:41:54.450424: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 262144, 149
# 2025-03-24 02:41:54.450426: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 294912, 18
# 2025-03-24 02:41:54.450427: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 524288, 9
# 2025-03-24 02:41:54.450428: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 589824, 18
# 2025-03-24 02:41:54.450430: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 1048576, 81
# 2025-03-24 02:41:54.450431: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 1179648, 9
# 2025-03-24 02:41:54.450432: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 4194304, 2
# 2025-03-24 02:41:54.450434: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 8388608, 3
# 2025-03-24 02:41:54.450435: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 16777216, 47
# 2025-03-24 02:41:54.450437: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 33554432, 12
# 2025-03-24 02:41:54.450438: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 43778048, 1
# 2025-03-24 02:41:54.450440: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 67108864, 27
# 2025-03-24 02:41:54.450441: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 134217728, 9
# 2025-03-24 02:41:54.450442: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 175112192, 1
# 2025-03-24 02:41:54.450444: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 175898624, 1
# 2025-03-24 02:41:54.450445: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 268435456, 6
# 2025-03-24 02:41:54.450446: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 536870912, 6
# 2025-03-24 02:41:54.450448: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:66] 703594496, 1
# 2025-03-24 02:41:54.450451: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:97] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 12348030976
# 2025-03-24 02:41:54.450454: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:99] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 10340177897
# 2025-03-24 02:41:54.450456: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:100] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 14361296896
# 2025-03-24 02:41:54.450458: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:101] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 13458384037
# 2025-03-24 02:41:54.450491: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at conv_grad_input_ops.cc:345 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[16,512,512,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator gpu_async_0
# 2025-03-24 02:41:54.450658: I tensorflow/core/framework/local_rendezvous.cc:425] Local rendezvous send item cancelled. Key hash: 6482532027842126477
# 2025-03-24 02:41:54.450682: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 2797218292212061033
# 2025-03-24 02:41:54.450687: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 12183461749239899167
# 2025-03-24 02:41:54.450692: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 18443817153041642899
# 2025-03-24 02:41:54.450693: I tensorflow/core/framework/local_rendezvous.cc:425] Local rendezvous send item cancelled. Key hash: 10898710706611749881
# 2025-03-24 02:41:54.450698: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 14948231229119457791
# 2025-03-24 02:41:54.450702: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 10477008847342832385
# 2025-03-24 02:41:54.450706: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 18179743736501157291
# 2025-03-24 02:41:54.450711: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 17978854443677793865
# 2025-03-24 02:41:54.450716: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 3345283421734744872
# 2025-03-24 02:41:54.450720: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 17854548497477096484
# 2025-03-24 02:41:54.450725: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 4341565883634840888
# 2025-03-24 02:41:54.450731: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 12007540324836694270
# 2025-03-24 02:41:54.450737: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 9834134694729341040
# 2025-03-24 02:41:54.450742: I tensorflow/core/framework/local_rendezvous.cc:421] Local rendezvous recv item cancelled. Key hash: 11901593816390945522
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[7], line 36
#      25 callbacks = [
#      26         tf.keras.callbacks.TensorBoard(log_dir='logs'),
#      27         tf.keras.callbacks.ModelCheckpoint(
#    (...)
#      32             save_best_only=True,
#      33             verbose=1)]
#      35 start_time = time.time()
# ---> 36 model.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=16, epochs=150, callbacks=callbacks)
#      37 end_time = time.time()
#      38 training_time = end_time - start_time
#
# File ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node gradient_tape/model/conv2d_14/Conv2D/Conv2DBackpropInput defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_881002/678085160.py", line 36, in <module>
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1154, in train_step
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 543, in minimize
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 276, in compute_gradients
#
# Detected at node gradient_tape/model/conv2d_14/Conv2D/Conv2DBackpropInput defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/tmp/ipykernel_881002/678085160.py", line 36, in <module>
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1807, in fit
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1401, in train_function
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1384, in step_function
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1373, in run_step
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/engine/training.py", line 1154, in train_step
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 543, in minimize
#
#   File "/home/mbouzon/.local/lib/python3.10/site-packages/keras/src/optimizers/optimizer.py", line 276, in compute_gradients
#
# 2 root error(s) found.
#   (0) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[16,512,512,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator gpu_async_0
# 	 [[{{node gradient_tape/model/conv2d_14/Conv2D/Conv2DBackpropInput}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[confusion_matrix/assert_less_1/Assert/AssertGuard/pivot_f/_31/_211]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#   (1) RESOURCE_EXHAUSTED:  OOM when allocating tensor with shape[16,512,512,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator gpu_async_0
# 	 [[{{node gradient_tape/model/conv2d_14/Conv2D/Conv2DBackpropInput}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_424358]

# %%
acc_mean_fold = []
jacc_mean_fold = []
f1_mean_fold = []
prec_mean_fold = []
rec_mean_fold = []

acc_std_fold = []
jacc_std_fold = []
f1_std_fold = []
prec_std_fold = []
rec_std_fold = []


# Dicionário para armazenar métricas por fold
fold_metrics_summary = []

fold = 1
kf = KFold(n_splits=k, shuffle=True, random_state=28)
for train_ind, test_ind in tqdm(kf.split(X), total=kf.get_n_splits(), desc="k-fold"):
    X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]

    fold_metrics = []

    acc_fold = []
    jacc_fold = []
    f1_fold = []
    prec_fold = []
    rec_fold = []
    
    model_filepath = filepath = os.path.join(output_dir, f'model_{fold}fold.keras')
    model = tf.keras.models.load_model(model_filepath)

    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc_score = accuracy_score(sample_mask, predicted_mask)
        jacc_score = jaccard_score(sample_mask, predicted_mask)
        f1_score_val = f1_score(sample_mask, predicted_mask).numpy()
        prec_score = precision_score(sample_mask, predicted_mask)
        rec_score = recall_score(sample_mask, predicted_mask)

        acc_fold.append(acc_score)
        jacc_fold.append(jacc_score)
        f1_fold.append(f1_score_val)
        prec_fold.append(prec_score)
        rec_fold.append(rec_score)

        fold_metrics.append([i, acc_score, jacc_score, f1_score_val, prec_score, rec_score])
        
    # Salvando métricas por imagem
    with open(os.path.join(output_dir, f'metrics_fold{fold}.csv'), 'w', newline='') as csvfile:
        writer = csv.writer(csvfile, delimiter=';')
        writer.writerow(["Index", "Accuracy", "Jaccard", "DICE", "Precision", "Recall"])
        writer.writerows(fold_metrics)

    # Salvando a média do fold para cada métrica
    fold_metrics_summary.append([
        fold, np.mean(acc_fold), np.std(acc_fold),
        np.mean(jacc_fold), np.std(jacc_fold),
        np.mean(f1_fold), np.std(f1_fold),
        np.mean(prec_fold), np.std(prec_fold),
        np.mean(rec_fold), np.std(rec_fold)
    ])


    fold += 1

# Calculando médias gerais
acc_total = [m[1] for m in fold_metrics_summary]
jacc_total = [m[3] for m in fold_metrics_summary]
f1_total = [m[5] for m in fold_metrics_summary]
prec_total = [m[7] for m in fold_metrics_summary]
rec_total = [m[9] for m in fold_metrics_summary]

general_summary = [
    ["Fold", "Accuracy Mean", "Accuracy Std", "Jaccard Mean", "Jaccard Std",
     "DICE Mean", "DICE Std", "Precision Mean", "Precision Std", "Recall Mean", "Recall Std"]
]

general_summary.extend(fold_metrics_summary)

general_summary.append([
    "Overall Mean", np.mean(acc_total), np.std(acc_total),
    np.mean(jacc_total), np.std(jacc_total),
    np.mean(f1_total), np.std(f1_total),
    np.mean(prec_total), np.std(prec_total),
    np.mean(rec_total), np.std(rec_total)
])

# Salvando o resumo das métricas por fold e geral
with open(os.path.join(output_dir, 'metrics_summary.csv'), 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=';')
    writer.writerows(general_summary)

print("Métricas salvas com sucesso na pasta:", output_dir)

# %%
print("Accuracy: "+ str(np.mean(acc_total)*100) + " +- " + str(np.std(acc_total)*100))
print("Jaccard: "+ str(np.mean(jacc_total)*100) + " +- " + str(np.std(jacc_total)*100))
print("Dice: "+ str(np.mean(f1_total)*100) + " +- " + str(np.std(f1_total)*100))
print("Precision: "+ str(np.mean(prec_total)*100) + " +- " + str(np.std(prec_total)*100))
print("Recall: "+ str(np.mean(rec_total)*100) + " +- " + str(np.std(rec_total)*100))

# %%
best_fold = 2
best_model_filepath = filepath = os.path.join(output_dir, f'model_{best_fold}fold.keras')
best_model = tf.keras.models.load_model(best_model_filepath)

# %%
kf = KFold(n_splits=k, shuffle=True, random_state=28)
for i, (train_ind, test_ind) in enumerate(kf.split(X)):
    if i == (best_fold-1):
        X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]
        break

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input image', 'True mask', 'Predicted mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap='gray')
    plt.axis('off')
  plt.show()

# %%
i = random.randint(0, len(X_val))
sample_image = X_val[i]
sample_mask = y_val[i]
prediction = best_model.predict(sample_image[tf.newaxis, ...])[0]
predicted_mask = (prediction > 0.5).astype(np.uint8)
display([sample_image, sample_mask,predicted_mask])

sample_mask = y_val[i].astype(np.uint8).flatten()
predicted_mask = predicted_mask.flatten()


print("Accuracy: "+ str(accuracy_score(sample_mask, predicted_mask)))
print("Jaccard: "+ str(jaccard_score(sample_mask, predicted_mask)))
print("Dice: "+ str((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask))))
print("Precision: "+ str(precision_score(sample_mask, predicted_mask)))
print("Recall: "+ str(recall_score(sample_mask, predicted_mask)))
