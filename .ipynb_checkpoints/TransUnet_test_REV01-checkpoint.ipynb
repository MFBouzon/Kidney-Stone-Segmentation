# %% [markdown]
# # Kidney Stone Segmentation Using U-Net and Fully Convolutional Networks

# %% [markdown]
# ## Importing Libraries

# %%
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
import os
import random
import numpy as np

from keras_unet_collection import models
from tqdm import tqdm 

from PIL import Image
import cv2
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
# Out:
# 2024-11-06 17:10:43.856991: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-06 17:10:44.370481: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Parameters and Variable

# %%
#seeds = [13, 42, 1, 83, 76]
seeds = [13, 42]
np.random.seed = [0]

num_classes = 1
split_size = 0.2


IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

DATA_PATH = 'data/'

data_ids = next(os.walk(DATA_PATH+'/image'))[2]

X = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
y = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_GPU_ALLOCATOR']= 'cuda_malloc_async'

# %% [markdown]
# ## Read Dataset

# %%
print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(data_ids), total=len(data_ids)):   
    path = DATA_PATH
    img = imread(path + '/image/' + id_)[:,:]
    img = img.reshape(img.shape[0], img.shape[1], IMG_CHANNELS)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X[n] = img  #Fill empty X_train with values from img
    
    mask = imread(path + 'label/' + id_)
    mask = (mask >= 250)
    mask = np.expand_dims(resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                      preserve_range=True), axis=-1)
    y[n] = mask 
    #plt.axis("off")
    #imshow(y[n])
    #plt.show()
# Out:
# Resizing training images and masks
# 100%|█████████████████████████████████████████████████████████████████████████████████| 838/838 [00:18<00:00, 46.17it/s]

# %%
from tensorflow.keras import layers, models
import tensorflow as tf

def transunet(input_shape=(512, 512, 1), num_heads=4, transformer_depth=4, projection_dim=64):
    entradas = layers.Input(input_shape)
    
    # Codificador da U-Net
    def conv_block(x, filtros):
        x = layers.Conv2D(filtros, (3, 3), activation='relu', padding='same')(x)
        x = layers.Conv2D(filtros, (3, 3), activation='relu', padding='same')(x)
        return x

    c1 = conv_block(entradas, 64)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = conv_block(p1, 128)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = conv_block(p2, 256)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = conv_block(p3, 512)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Codificador convolucional final antes do Transformer
    c5 = conv_block(p4, 1024)

    # Transformer: Reformatando para entrada no Transformer (flatten + projection)
    # Converter mapa de características para uma sequência de patches
    patch_size = 1  # Considerando cada pixel do mapa de características como um "patch"
    num_patches = (input_shape[0] // 16) ** 2  # Tamanho reduzido após downsampling
    x = layers.Reshape((num_patches, -1))(c5)
    x = layers.Dense(projection_dim)(x)

    # Camadas do Transformer
    for _ in range(transformer_depth):
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        attention_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim, dropout=0.1)(x1, x1)
        x2 = layers.Add()([attention_output, x])
        
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = layers.Dense(projection_dim * 2, activation="relu")(x3)
        x3 = layers.Dense(projection_dim)(x3)
        x = layers.Add()([x3, x2])

    # Reformatando de volta para o mapa de características 2D
    x = layers.Reshape((input_shape[0] // 16, input_shape[1] // 16, projection_dim))(x)

    # Decodificador da U-Net com conexões de salto
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(x)
    u6 = layers.concatenate([u6, c4])
    c6 = conv_block(u6, 512)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = conv_block(u7, 256)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = conv_block(u8, 128)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = conv_block(u9, 64)

    saidas = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    # Construindo o modelo
    modelo = models.Model(inputs=[entradas], outputs=[saidas])
    return modelo

# Compilando o modelo
modelo = transunet()
modelo.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.Recall(name ='recall')])
# Out:
# 2024-11-06 17:11:03.716036: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:03.733145: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:03.733200: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:03.736026: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:03.736098: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:03.736118: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:04.415130: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:04.415194: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:04.415200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-06 17:11:04.415207: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-11-06 17:11:04.415211: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:238] Using CUDA malloc Async allocator for GPU: 0
# 2024-11-06 17:11:04.415339: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 17:11:04.415360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9332 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []


for f in range(1, len(seeds)):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=split_size, random_state=seeds[f])
    
    model = transunet()
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.Recall(name ='recall')])

    
    checkpoint_filepath = 'Unet++test' + str(f)+'fold.keras'
    callbacks = [
            tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss'),
            tf.keras.callbacks.TensorBoard(log_dir='logs'),
            tf.keras.callbacks.ModelCheckpoint(
                filepath=checkpoint_filepath,
                save_weights_only=False,
                monitor='val_recall',
                mode='max',
                save_best_only=True,
                verbose=1)]
    
    model.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=8, epochs=300, callbacks=callbacks)
    model.save('Unet++Modelo1.keras')

    loss = model.history.history['loss']
    val_loss = model.history.history['val_loss']

    plt.figure()
    plt.plot( loss, 'r', label='Training loss')
    plt.plot( val_loss, 'bo', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss Value')
    plt.ylim([0, 1])
    plt.legend()
    plt.show()


    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc.append(accuracy_score(sample_mask, predicted_mask))
        jacc.append(jaccard_score(sample_mask, predicted_mask))
        f1.append(f1_score(sample_mask, predicted_mask))
        prec.append(precision_score(sample_mask, predicted_mask))
        rec.append(recall_score(sample_mask, predicted_mask))

    #del model
    tf.keras.backend.clear_session()

    f+=1
    
    jacc = np.array(jacc)

    print(f"Accuracy: {np.mean(acc)} +- {np.std(acc)}")
    print(f"Jaccard: {np.mean(jacc)} +- {np.std(jacc)}")
    print(f"Dice: {(2*np.mean(jacc))/(1+np.mean(jacc))} +- {np.std(2*jacc/(1+jacc))}")
    print(f"F1 Score: {np.mean(f1)} +- {np.std(f1)}")
    print(f"Precision: {np.mean(prec)} +- {np.std(prec)}")
    print(f"Recall: {np.mean(rec)} +- {np.std(rec)}")
# Out:
# Epoch 1/300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730923867.691181   87556 service.cc:145] XLA service 0x7f03d00036c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730923867.691656   87556 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2024-11-06 17:11:07.769077: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-06 17:11:09.290734: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2024-11-06 17:11:12.915838: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:308] gpu_async_0 cuMemAllocAsync failed to allocate 44330909696 bytes: CUDA error: out of memory (CUDA_ERROR_OUT_OF_MEMORY)
#  Reported by CUDA: Free memory/Total memory: 7337934848/12878086144
# 2024-11-06 17:11:12.915870: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:313] Stats: Limit:                      9785311232
# InUse:                       779477849
# MaxInUse:                   3102104665
# NumAllocs:                         810
# MaxAllocSize:               2451718144
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-11-06 17:11:12.915882: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:62] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2024-11-06 17:11:12.915885: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1, 1
# 2024-11-06 17:11:12.915886: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 4, 47
# 2024-11-06 17:11:12.915888: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 8, 3
# 2024-11-06 17:11:12.915889: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 64, 5
# 2024-11-06 17:11:12.915890: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 128, 5
# 2024-11-06 17:11:12.915892: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 256, 14
# 2024-11-06 17:11:12.915893: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 512, 11
# 2024-11-06 17:11:12.915894: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 576, 3
# 2024-11-06 17:11:12.915895: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1024, 11
# 2024-11-06 17:11:12.915897: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1028, 1
# 2024-11-06 17:11:12.915898: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2048, 7
# 2024-11-06 17:11:12.915899: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 9216, 3
# 2024-11-06 17:11:12.915901: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 18432, 3
# 2024-11-06 17:11:12.915902: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 36864, 3
# 2024-11-06 17:11:12.915903: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 73728, 3
# 2024-11-06 17:11:12.915904: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 131072, 3
# 2024-11-06 17:11:12.915906: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 147456, 5
# 2024-11-06 17:11:12.915907: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 184320, 3
# 2024-11-06 17:11:12.915908: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 294912, 3
# 2024-11-06 17:11:12.915909: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 524288, 3
# 2024-11-06 17:11:12.915911: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 589824, 5
# 2024-11-06 17:11:12.915912: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 737280, 3
# 2024-11-06 17:11:12.915913: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1179648, 3
# 2024-11-06 17:11:12.915914: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2097152, 8
# 2024-11-06 17:11:12.915916: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2359296, 5
# 2024-11-06 17:11:12.915917: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2949120, 3
# 2024-11-06 17:11:12.915918: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 9437184, 3
# 2024-11-06 17:11:12.915920: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 11796480, 3
# 2024-11-06 17:11:12.915921: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 16779264, 1
# 2024-11-06 17:11:12.915922: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 28573696, 1
# 2024-11-06 17:11:12.915924: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 83886080, 2
# 2024-11-06 17:11:12.915925: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 100663296, 1
# 2024-11-06 17:11:12.915926: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 175636480, 2
# 2024-11-06 17:11:12.915930: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:96] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 3288334336
# 2024-11-06 17:11:12.915931: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:98] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 779477849
# 2024-11-06 17:11:12.915933: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:99] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 3288334336
# 2024-11-06 17:11:12.915934: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:100] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 3102104665
# 2024-11-06 17:11:13.568127: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:308] gpu_async_0 cuMemAllocAsync failed to allocate 35468083200 bytes: CUDA error: out of memory (CUDA_ERROR_OUT_OF_MEMORY)
#  Reported by CUDA: Free memory/Total memory: 7337934848/12878086144
# 2024-11-06 17:11:13.568169: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:313] Stats: Limit:                      9785311232
# InUse:                       760341337
# MaxInUse:                   3102104665
# NumAllocs:                         830
# MaxAllocSize:               2451718144
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-11-06 17:11:13.568183: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:62] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2024-11-06 17:11:13.568185: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1, 1
# 2024-11-06 17:11:13.568187: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 4, 47
# 2024-11-06 17:11:13.568188: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 8, 3
# 2024-11-06 17:11:13.568190: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 64, 5
# 2024-11-06 17:11:13.568191: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 128, 5
# 2024-11-06 17:11:13.568192: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 256, 14
# 2024-11-06 17:11:13.568194: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 512, 11
# 2024-11-06 17:11:13.568195: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 576, 3
# 2024-11-06 17:11:13.568196: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1024, 11
# 2024-11-06 17:11:13.568198: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1028, 1
# 2024-11-06 17:11:13.568199: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2048, 7
# 2024-11-06 17:11:13.568200: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 9216, 3
# 2024-11-06 17:11:13.568202: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 18432, 3
# 2024-11-06 17:11:13.568203: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 36864, 3
# 2024-11-06 17:11:13.568205: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 73728, 3
# 2024-11-06 17:11:13.568206: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 131072, 3
# 2024-11-06 17:11:13.568207: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 147456, 5
# 2024-11-06 17:11:13.568208: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 184320, 3
# 2024-11-06 17:11:13.568210: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 294912, 3
# 2024-11-06 17:11:13.568211: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 524288, 3
# 2024-11-06 17:11:13.568212: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 589824, 5
# 2024-11-06 17:11:13.568214: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 737280, 3
# 2024-11-06 17:11:13.568215: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1179648, 3
# 2024-11-06 17:11:13.568216: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2097152, 8
# 2024-11-06 17:11:13.568218: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2359296, 5
# 2024-11-06 17:11:13.568219: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2949120, 3
# 2024-11-06 17:11:13.568220: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 9437184, 3
# 2024-11-06 17:11:13.568222: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 11796480, 3
# 2024-11-06 17:11:13.568223: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 16779264, 1
# 2024-11-06 17:11:13.568224: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 26214400, 1
# 2024-11-06 17:11:13.568226: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 83886080, 3
# 2024-11-06 17:11:13.568228: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 175636480, 2
# 2024-11-06 17:11
E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:96] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 7784628224
# 2024-11-06 17:17:51.498397: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:98] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 288225826
# 2024-11-06 17:17:51.498398: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:99] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 7784628224
# 2024-11-06 17:17:51.498400: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:100] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 7747923033
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.999686218443371 +- 0.0005498322640974032
# Jaccard: 0.6607610303314116 +- 0.2727221256469761
# Dice: 0.7957328215963185 +- 0.25849505054194655
# F1 Score: 0.7541231363727408 +- 0.25849505054194655
# Precision: 0.954392180153511 +- 0.18700050778962327
# Recall: 0.6668808972673972 +- 0.2762954161300091

# %%
jacc = np.array(jacc)

print(f"Accuracy: {np.mean(acc)} +- {np.std(acc)}")
print(f"Jaccard: {np.mean(jacc)} +- {np.std(jacc)}")
print(f"Dice: {(2*np.mean(jacc))/(1+np.mean(jacc))} +- {np.std(2*jacc/(1+jacc))}")
print(f"F1 Score: {np.mean(f1)} +- {np.std(f1)}")
print(f"Precision: {np.mean(prec)} +- {np.std(prec)}")
print(f"Recall: {np.mean(rec)} +- {np.std(rec)}")
# Out:
# Accuracy: 0.999686218443371 +- 0.0005498322640974032
# Jaccard: 0.6607610303314116 +- 0.2727221256469761
# Dice: 0.7957328215963185 +- 0.25849505054194655
# F1 Score: 0.7541231363727408 +- 0.25849505054194655
# Precision: 0.954392180153511 +- 0.18700050778962327
# Recall: 0.6668808972673972 +- 0.2762954161300091

# %%
import tensorflow as tf
best_model = tf.keras.models.load_model('Unet++modelo1.keras')

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input image', 'True mask', 'Predicted mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    image = display_list[i]
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap='gray')
    plt.axis('off')
  plt.show()
   
i = random.randint(0, len(X_val) - 1)
sample_image = X_val[i]
sample_mask = y_val[i]
prediction = best_model.predict(sample_image[tf.newaxis, ...])[0]
predicted_mask = (prediction > 0.5).astype(np.uint8)
predicted_mask = predicted_mask[1:]
display([sample_image, sample_mask,predicted_mask])
sample_mask = y_val[i].astype(np.uint8).flatten()

predicted_mask = predicted_mask.flatten()


print("Accuracy: "+ str(accuracy_score(sample_mask, predicted_mask)))
print("Jaccard: "+ str(jaccard_score(sample_mask, predicted_mask)))
print("Dice: "+ str((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask))))
print("Precision: "+ str(precision_score(sample_mask, predicted_mask)))
print("Recall: "+ str(recall_score(sample_mask, predicted_mask)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 26
#      21 sample_mask = y_val[i].astype(np.uint8).flatten()
#      23 predicted_mask = predicted_mask.flatten()
# ---> 26 print("Accuracy: "+ str(accuracy_score(sample_mask, predicted_mask)))
#      27 print("Jaccard: "+ str(jaccard_score(sample_mask, predicted_mask)))
#      28 print("Dice: "+ str((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask))))
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
#     199         r"parameter of \w+ must be",
#     200         f"parameter of {func.__qualname__} must be",
#     201         str(e),
#     202     )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:221, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     155 """Accuracy classification score.
#     156
#     157 In multilabel classification, this function computes subset accuracy:
#    (...)
#     217 0.5
#     218 """
#     220 # Compute accuracy for each possible representation
# --> 221 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     222 check_consistent_length(y_true, y_pred, sample_weight)
#     223 if y_type.startswith("multilabel"):
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:86, in _check_targets(y_true, y_pred)
#      59 def _check_targets(y_true, y_pred):
#      60     """Check that y_true and y_pred belong to the same classification task.
#      61
#      62     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      84     y_pred : array or indicator matrix
#      85     """
# ---> 86     check_consistent_length(y_true, y_pred)
#      87     type_true = type_of_target(y_true, input_name="y_true")
#      88     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [262144, 261632]

# %%
predicted_mask.shape

# %% [markdown]
# Acuraccy:  0.9998064804077148
# Jaccard:  0.7504550150031974
# F1 Score:  0.8574399325558522
# Precision:  0.9923892538866844
# Recall:  0.7547991292301603

# %%
sample_image.shape

# %%
sample_mask.shape
