# %%
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
import os
import random
import numpy as np

from keras_unet_collection import models

from tqdm import tqdm 

from PIL import Image
import cv2
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import KFold
# Out:
# 2024-11-06 15:04:03.676380: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-06 15:04:04.102536: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
num_classes = 1
k = 5


IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

DATA_PATH = 'data/'

data_ids = next(os.walk(DATA_PATH+'/image'))[2]

X = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
y = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_GPU_ALLOCATOR']= 'cuda_malloc_async'

# %%
print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(data_ids), total=len(data_ids)):   
    path = DATA_PATH
    img = imread(path + '/image/' + id_)[:,:]
    img = img.reshape(img.shape[0], img.shape[1], IMG_CHANNELS)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X[n] = img  #Fill empty X_train with values from img
    
    mask = imread(path + 'label/' + id_)
    mask = (mask >= 250)
    mask = np.expand_dims(resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                      preserve_range=True), axis=-1)
    y[n] = mask 
    #plt.axis("off")
    #imshow(y[n])
    #plt.show()
# Out:
# Resizing training images and masks
# 100%|█████████████████████████████████████████████████████████████████████████████████| 838/838 [00:18<00:00, 46.16it/s]

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

kf = KFold(n_splits=k, shuffle=True, random_state=28)
f = 1

for train_ind, test_ind in kf.split(X):
    X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]
    
    model = models.unet_plus_2d((512, 512, 1), [16, 32, 64, 128], n_labels=1,
                            stack_num_down=2, stack_num_up=2,
                            activation='LeakyReLU', output_activation='Sigmoid',
                            batch_norm=False, pool='max', unpool=False, deep_supervision=True, name='xnet')

    # Define metrics for each output
    metrics = ['accuracy', tf.keras.metrics.Recall(name='recall')]
    metrics_dict = {output_name: metrics for output_name in model.output_names}

    model.compile(
    optimizer='adam',
    loss='binary_crossentropy',  # Use a single loss function for the final output
    metrics= metrics_dict
     )
    
    checkpoint_filepath = 'Unet++test' + str(f)+'fold.keras'
    callbacks = [
            tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss'),
            tf.keras.callbacks.TensorBoard(log_dir='logs'),
            tf.keras.callbacks.ModelCheckpoint(
                filepath=checkpoint_filepath,
                save_weights_only=False,
                monitor='val_recall',
                mode='max',
                save_best_only=True,
                verbose=1)]
    
    model.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=8, epochs=300, callbacks=callbacks)
    model.save('Unet++Modelo1.keras')
    
    loss = model.history.history['loss']
    val_loss = model.history.history['val_loss']
    
    plt.figure()
    plt.plot( loss, 'r', label='Training loss')
    plt.plot( val_loss, 'bo', label='Validation loss')
    plt.title('Training and Validation Loss - Fold' + str(f))
    plt.xlabel('Epoch')
    plt.ylabel('Loss Value')
    plt.ylim([0, 1])
    plt.legend()
    plt.show()
    
    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc.append(accuracy_score(sample_mask, predicted_mask))
        jacc.append(jaccard_score(sample_mask, predicted_mask))
        f1.append(f1_score(sample_mask, predicted_mask))
        prec.append(precision_score(sample_mask, predicted_mask))
        rec.append(recall_score(sample_mask, predicted_mask))

    del model 

    tf.keras.backend.clear_session()

    f+=1
    
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [64, 64, 64]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 256
# 2024-11-04 12:44:48.104513: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:48.246300: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:48.246355: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:48.258803: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:48.258867: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:48.258892: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:49.495592: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:49.496189: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:49.496200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-04 12:44:49.496210: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-11-04 12:44:49.496215: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:238] Using CUDA malloc Async allocator for GPU: 0
# 2024-11-04 12:44:49.496378: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-04 12:44:49.496844: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9332 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# ----------
# deep_supervision = True
# names of output tensors are listed as follows ("sup0" is the shallowest supervision layer;
# "final" is the final output layer):
#
# 	unet3plus_output_sup0_activation
# 	unet3plus_output_sup1_activation
# 	unet3plus_output_sup2_activation
# 	unet3plus_output_final_activation
# Epoch 1/300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730735098.342682  321228 service.cc:145] XLA service 0x7f9b08003d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730735098.343487  321228 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2024-11-04 12:44:58.600103: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-04 12:45:01.851969: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 2024-11-04 12:45:11.951801: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[16,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-04 12:45:12.046419: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.09472567s
# Trying algorithm eng0{} for conv (f32[16,64,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,512,512]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-04 12:45:20.140051: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng3{k11=0} for conv (f32[16,256,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,128,128]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-04 12:45:20.633567: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:308] gpu_async_0 cuMemAllocAsync failed to allocate 18414174208 bytes: CUDA error: out of memory (CUDA_ERROR_OUT_OF_MEMORY)
#  Reported by CUDA: Free memory/Total memory: 933232640/12878086144
# 2024-11-04 12:45:20.633612: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:313] Stats: Limit:                      9785311232
# InUse:                      1693233241
# MaxInUse:                   9091543129
# NumAllocs:                         796
# MaxAllocSize:               4849205248
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-11-04 12:45:20.633627: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:62] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2024-11-04 12:45:20.633630: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1, 1
# 2024-11-04 12:45:20.633632: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 4, 43
# 2024-11-04 12:45:20.633634: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 8, 3
# 2024-11-04 12:45:20.633635: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 36, 4
# 2024-11-04 12:45:20.633637: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 256, 75
# 2024-11-04 12:45:20.633638: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 512, 9
# 2024-11-04 12:45:20.633639: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1024, 21
# 2024-11-04 12:45:20.633641: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1028, 1
# 2024-11-04 12:45:20.633642: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2048, 9
# 2024-11-04 12:45:20.633644: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2304, 2
# 2024-11-04 12:45:20.633645: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 9216, 4
# 2024-11-04 12:45:20.633646: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 18432, 2
# 2024-11-04 12:45:20.633648: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 147456, 8
# 2024-11-04 12
{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,256,256]{3,2,1,0}, f32[256,64,3,3]{3,2,1,0}), window={size=3x3 stride=2x2}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}} is taking a while...
# 2024-11-04 12:46:17.522980: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:308] gpu_async_0 cuMemAllocAsync failed to allocate 4311744512 bytes: CUDA error: out of memory (CUDA_ERROR_OUT_OF_MEMORY)
#  Reported by CUDA: Free memory/Total memory: 0/12878086144
# 2024-11-04 12:46:17.523022: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:313] Stats: Limit:                      9785311232
# InUse:                     11761922153
# MaxInUse:                  11761922153
# NumAllocs:                        1385
# MaxAllocSize:               5427724288
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-11-04 12:46:17.523035: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:62] Histogram of current allocation: (allocation_size_in_bytes, nb_allocation_of_that_sizes), ...;
# 2024-11-04 12:46:17.523038: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1, 1
# 2024-11-04 12:46:17.523040: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 4, 43
# 2024-11-04 12:46:17.523041: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 8, 3
# 2024-11-04 12:46:17.523043: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 36, 4
# 2024-11-04 12:46:17.523044: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 256, 75
# 2024-11-04 12:46:17.523046: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 512, 9
# 2024-11-04 12:46:17.523047: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1024, 21
# 2024-11-04 12:46:17.523048: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1028, 1
# 2024-11-04 12:46:17.523050: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2048, 9
# 2024-11-04 12:46:17.523051: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2304, 2
# 2024-11-04 12:46:17.523052: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 9216, 4
# 2024-11-04 12:46:17.523054: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 18432, 2
# 2024-11-04 12:46:17.523055: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 147456, 8
# 2024-11-04 12:46:17.523056: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 294912, 5
# 2024-11-04 12:46:17.523058: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 589824, 8
# 2024-11-04 12:46:17.523059: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1179648, 6
# 2024-11-04 12:46:17.523061: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 1769472, 4
# 2024-11-04 12:46:17.523062: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 2359296, 2
# 2024-11-04 12:46:17.523063: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 4194304, 5
# 2024-11-04 12:46:17.523065: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 4718592, 2
# 2024-11-04 12:46:17.523066: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 9437184, 2
# 2024-11-04 12:46:17.523067: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 18546688, 1
# 2024-11-04 12:46:17.523069: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 175636480, 5
# 2024-11-04 12:46:17.523070: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 3238002688, 1
# 2024-11-04 12:46:17.523071: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 3239772176, 1
# 2024-11-04 12:46:17.523073: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:65] 4311744512, 1
# 2024-11-04 12:46:17.523076: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:96] CU_MEMPOOL_ATTR_RESERVED_MEM_CURRENT: 11777605632
# 2024-11-04 12:46:17.523078: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:98] CU_MEMPOOL_ATTR_USED_MEM_CURRENT: 11761922153
# 2024-11-04 12:46:17.523079: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:99] CU_MEMPOOL_ATTR_RESERVED_MEM_HIGH: 20635975680
# 2024-11-04 12:46:17.523081: E external/local_xla/xla/stream_executor/gpu/gpu_cudamallocasync_allocator.cc:100] CU_MEMPOOL_ATTR_USED_MEM_HIGH: 11761922153
# 2024-11-04 12:46:17.560252: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at xla_ops.cc:580 : UNKNOWN: Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.62 = (f32[16,256,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,192,512,512]{3,2,1,0} %concatenate.9, f32[256,192,3,3]{3,2,1,0} %transpose.549), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="functional_1_1/unet3plus_fusion_conv_2_0_1/convolution" source_file="/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/ops.py" source_line=1177}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}}
#
# Original error: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 4311744512 bytes.
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning.
# 2024-11-04 12:46:17.562028: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: UNKNOWN: Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.62 = (f32[16,256,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,192,512,512]{3,2,1,0} %concatenate.9, f32[256,192,3,3]{3,2,1,0} %transpose.549), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="functional_1_1/unet3plus_fusion_conv_2_0_1/convolution" source_file="/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/ops.py" source_line=1177}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}}
#
# Original error: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 4311744512 bytes.
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning.
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[5], line 54
#      42 checkpoint_filepath = 'model_' + str(f)+'fold.keras'
#      43 callbacks = [
#      44         tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
#      45         tf.keras.callbacks.TensorBoard(log_dir='logs'),
#    (...)
#      51             save_best_only=True,
#      52             verbose=1)]
# ---> 54 model.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=16, epochs=300, callbacks=callbacks)
#      56 loss = model.history.history['loss']
#      57 val_loss = model.history.history['val_loss']
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# UnknownError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/runpy.py", line 87, in _run_code
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel_launcher.py", line 17, in <module>
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 725, in start
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/asyncio/events.py", line 80, in _run
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#
#   File "/tmp/ipykernel_321117/3370683537.py", line 54, in <module>
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 325, in fit
#
#   File "/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py", line 118, in one_step_on_iterator
#
# Failed to determine best cudnn convolution algorithm for:
# %cudnn-conv.62 = (f32[16,256,512,512]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,192,512,512]{3,2,1,0} %concatenate.9, f32[256,192,3,3]{3,2,1,0} %transpose.549), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convForward", metadata={op_type="Conv2D" op_name="functional_1_1/unet3plus_fusion_conv_2_0_1/convolution" source_file="/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/ops.py" source_line=1177}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0}}
#
# Original error: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 4311744512 bytes.
#
# To ignore this failure and try to use a fallback algorithm (which may have suboptimal performance), use XLA_FLAGS=--xla_gpu_strict_conv_algorithm_picker=false.  Please also file a bug for the root cause of failing autotuning.
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_one_step_on_iterator_21093]

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))

# %%
acc_mean_fold = []
jacc_mean_fold = []
f1_mean_fold = []
prec_mean_fold = []
rec_mean_fold = []

acc_std_fold = []
jacc_std_fold = []
f1_std_fold = []
prec_std_fold = []
rec_std_fold = []


f = 0
kf = KFold(n_splits=k, shuffle=True, random_state=28)
for train_ind, test_ind in tqdm(kf.split(X), total=kf.get_n_splits(), desc="k-fold"):
    X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]

    acc= []
    jacc = []
    f1 = []
    prec = []
    rec = []
    
    model = tf.keras.models.load_model('model_'+str(f+1)+'fold.h5')

    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc.append(accuracy_score(sample_mask, predicted_mask))
        jacc.append(jaccard_score(sample_mask, predicted_mask))
        f1.append(f1_score(sample_mask, predicted_mask))
        prec.append(precision_score(sample_mask, predicted_mask))
        rec.append(recall_score(sample_mask, predicted_mask))

    acc_mean_fold.append(np.mean(acc))
    acc_std_fold.append(np.std(acc))
    jacc_mean_fold.append(np.mean(jacc))
    jacc_std_fold.append(np.std(jacc))
    f1_mean_fold.append(np.mean(f1))
    f1_std_fold.append(np.std(f1))
    prec_mean_fold.append(np.mean(prec))
    prec_std_fold.append(np.std(prec))
    rec_mean_fold.append(np.mean(rec))
    rec_std_fold.append(np.std(rec))
    
    print("Model - Fold" + str(f+1)+ "Accuracy: " + str(acc_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Jaccard: " + str(jacc_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Dice: " + str(f1_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Precision: " + str(prec_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Recall: " + str(rec_mean_fold[-1]))

    f += 1
# Out:
# k-fold:   0%|                                                                                     | 0/5 [00:00<?, ?it/s]/home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# k-fold:  20%|███████████████▍                                                             | 1/5 [00:30<02:02, 30.53s/it]
# Model - Fold1Accuracy: 0.9999462990533738
# Model - Fold1Jaccard: 0.9187525201741183
# Model - Fold1Dice: 0.9513527624956103
# Model - Fold1Precision: 0.944259975025257
# Model - Fold1Recall: 0.9629832362797363
# k-fold:  40%|██████████████████████████████▊                                              | 2/5 [01:00<01:31, 30.43s/it]
# Model - Fold2Accuracy: 0.999950477055141
# Model - Fold2Jaccard: 0.894915812416774
# Model - Fold2Dice: 0.9410717794643
# Model - Fold2Precision: 0.9022293088566278
# Model - Fold2Recall: 0.9885731329803736
# k-fold:  60%|██████████████████████████████████████████████▏                              | 3/5 [01:31<01:00, 30.38s/it]
# Model - Fold3Accuracy: 0.9999080158415294
# Model - Fold3Jaccard: 0.8188939053827247
# Model - Fold3Dice: 0.8937424364863357
# Model - Fold3Precision: 0.822083917440476
# Model - Fold3Recall: 0.9941403850283234
# k-fold:  80%|█████████████████████████████████████████████████████████████▌               | 4/5 [02:02<00:30, 30.54s/it]
# Model - Fold4Accuracy: 0.9999386450487696
# Model - Fold4Jaccard: 0.8716610961132153
# Model - Fold4Dice: 0.9293192731478103
# Model - Fold4Precision: 0.8769388953589097
# Model - Fold4Recall: 0.9939014820480496
# k-fold: 100%|█████████████████████████████████████████████████████████████████████████████| 5/5 [02:32<00:00, 30.52s/it]
# Model - Fold5Accuracy: 0.999915300015204
# Model - Fold5Jaccard: 0.8170915371657571
# Model - Fold5Dice: 0.8930179350642634
# Model - Fold5Precision: 0.8178295846547864
# Model - Fold5Recall: 0.9990411194260411

# %%
print("Accuracy: "+ str(np.mean(acc_mean_fold)*100) + " +- " + str(np.std(acc_std_fold)*100))
print("Jaccard: "+ str(np.mean(jacc_mean_fold)*100) + " +- " + str(np.std(jacc_std_fold)*100))
print("Dice: "+ str(np.mean(f1_mean_fold)*100) + " +- " + str(np.std(f1_std_fold)*100))
print("Precision: "+ str(np.mean(prec_mean_fold)*100) + " +- " + str(np.std(prec_std_fold)*100))
print("Recall: "+ str(np.mean(rec_mean_fold)*100) + " +- " + str(np.std(rec_std_fold)*100))
# Out:
# Accuracy: 99.99317474028035 +- 0.005555623613547455
# Jaccard: 86.42629742505179 +- 1.8090608968500312
# Dice: 92.1700837331664 +- 2.112926733488158
# Precision: 87.26683362672114 +- 1.8959768200068368
# Recall: 98.77278711525047 +- 2.9380004678423832

# %%
best_model = tf.keras.models.load_model('UNET3Plus 5-fold models/model_1fold.keras')
# Out:
# 2024-11-06 15:04:27.648538: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:27.665891: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:27.665939: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:27.668942: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:27.669004: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:27.669024: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:28.366090: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:28.366171: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:28.366178: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-06 15:04:28.366187: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-11-06 15:04:28.366191: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:238] Using CUDA malloc Async allocator for GPU: 0
# 2024-11-06 15:04:28.366328: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-06 15:04:28.366349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9332 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
kf = KFold(n_splits=k, shuffle=True, random_state=28)
for i, (train_ind, test_ind) in enumerate(kf.split(X)):
    if i == 0:
        X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]
        break

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input image', 'True mask', 'Predicted mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap='gray')
    plt.axis('off')
  plt.show()
  
i = random.randint(0, len(X_val))
sample_image = X_val[i]
sample_mask = y_val[i]
prediction = best_model.predict(sample_image[tf.newaxis, ...])[0]
predicted_mask = (prediction > 0.5).astype(np.uint8)
display([sample_image, sample_mask,predicted_mask])

sample_mask = y_val[i].astype(np.uint8).flatten()
predicted_mask = predicted_mask.flatten()


print("Accuracy: "+ str(accuracy_score(sample_mask, predicted_mask)))
print("Jaccard: "+ str(jaccard_score(sample_mask, predicted_mask)))
print("Dice: "+ str((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask))))
print("Precision: "+ str(precision_score(sample_mask, predicted_mask)))
print("Recall: "+ str(recall_score(sample_mask, predicted_mask)))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730916269.738951   16190 service.cc:145] XLA service 0x7f7e28004b80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730916269.738990   16190 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2024-11-06 15:04:29.748006: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-06 15:04:30.981002: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# I0000 00:00:1730916272.952824   16190 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Accuracy: 0.999908447265625
# Jaccard: 0.957968476357268
# Dice: 0.9785330948121647
# Precision: 0.9927404718693285
# Recall: 0.9647266313932981

# %%
predicted_mask.shape
# Out:
# (262144,)
