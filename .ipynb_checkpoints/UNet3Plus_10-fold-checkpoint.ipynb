# %%
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
import os
import random
import numpy as np

from keras_unet_collection import models

from tqdm import tqdm 

from PIL import Image
import cv2
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.model_selection import KFold
# Out:
# 2024-11-11 11:52:52.909191: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-11 11:52:53.352999: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
num_classes = 1
k = 5


IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

DATA_PATH = 'data/'

data_ids = next(os.walk(DATA_PATH+'/image'))[2]

X = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
y = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_GPU_ALLOCATOR']= 'cuda_malloc_async'

# %%
print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(data_ids), total=len(data_ids)):   
    path = DATA_PATH
    img = imread(path + '/image/' + id_)[:,:]
    img = img.reshape(img.shape[0], img.shape[1], IMG_CHANNELS)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X[n] = img  #Fill empty X_train with values from img
    
    mask = imread(path + 'label/' + id_)
    mask = (mask >= 250)
    mask = np.expand_dims(resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                      preserve_range=True), axis=-1)
    y[n] = mask 
    #plt.axis("off")
    #imshow(y[n])
    #plt.show()
# Out:
# Resizing training images and masks
# 100%|█████████████████████████████████████████████████████████████████████████████████| 838/838 [00:18<00:00, 45.25it/s]

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []

kf = KFold(n_splits=k, shuffle=True, random_state=28)
f = 1

for train_ind, test_ind in kf.split(X):
    X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]
    
    y_train = {
        'unet3plus_output_sup0_activation': y_train,
        'unet3plus_output_sup1_activation': y_train,
        'unet3plus_output_sup2_activation': y_train,
        'unet3plus_output_final_activation': y_train
    }
    y_val = {
        'unet3plus_output_sup0_activation': y_val,
        'unet3plus_output_sup1_activation': y_val,
        'unet3plus_output_sup2_activation': y_val,
        'unet3plus_output_final_activation': y_val
    }

    model = models.unet_3plus_2d((512, 512, 1), n_labels=1, filter_num_down=[16, 32, 64, 128],
                             filter_num_skip='auto', filter_num_aggregate='auto',
                             stack_num_down=2, stack_num_up=1, activation='ReLU', output_activation='Sigmoid',
                             batch_norm=True, pool='max', unpool=False, deep_supervision=True, name='unet3plus')
    
    model.compile(
        optimizer='adam',
        loss={
            'unet3plus_output_sup0_activation': 'binary_crossentropy',
            'unet3plus_output_sup1_activation': 'binary_crossentropy',
            'unet3plus_output_sup2_activation': 'binary_crossentropy',
            'unet3plus_output_final_activation': 'binary_crossentropy'
        },
        metrics={'unet3plus_output_final_activation': ['accuracy', tf.keras.metrics.Recall(name='recall')]}
    )
    
    checkpoint_filepath = 'model_' + str(f)+'fold.keras'
    callbacks = [
            tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
            tf.keras.callbacks.TensorBoard(log_dir='logs'),
            tf.keras.callbacks.ModelCheckpoint(
                filepath=checkpoint_filepath,
                save_weights_only=False,
                monitor='val_recall',
                mode='max',
                save_best_only=True,
                verbose=1)]
    
    model.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=16, epochs=300, callbacks=callbacks)
    model.save('model_' + str(f)+'fold.keras')
    loss = model.history.history['loss']
    val_loss = model.history.history['val_loss']
    
    plt.figure()
    plt.plot( loss, 'r', label='Training loss')
    plt.plot( val_loss, 'bo', label='Validation loss')
    plt.title('Training and Validation Loss - Fold' + str(f))
    plt.xlabel('Epoch')
    plt.ylabel('Loss Value')
    plt.ylim([0, 1])
    plt.legend()
    plt.show()
    
    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val['unet3plus_output_final_activation'][i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc.append(accuracy_score(sample_mask, predicted_mask))
        jacc.append(jaccard_score(sample_mask, predicted_mask))
        f1.append(f1_score(sample_mask, predicted_mask))
        prec.append(precision_score(sample_mask, predicted_mask))
        rec.append(recall_score(sample_mask, predicted_mask))

    del model 

    tf.keras.backend.clear_session()

    f+=1
    
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [16, 16, 16]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 64
# 2024-11-11 11:53:12.992035: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.009246: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.009311: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.011193: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.011249: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.011272: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.765979: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.766042: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.766047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-11-11 11:53:13.766054: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2024-11-11 11:53:13.766058: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:238] Using CUDA malloc Async allocator for GPU: 0
# 2024-11-11 11:53:13.766187: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-11 11:53:13.766208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9332 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# ----------
# deep_supervision = True
# names of output tensors are listed as follows ("sup0" is the shallowest supervision layer;
# "final" is the final output layer):
#
# 	unet3plus_output_sup0_activation
# 	unet3plus_output_sup1_activation
# 	unet3plus_output_sup2_activation
# 	unet3plus_output_final_activation
# Epoch 1/300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731336802.047149    2531 service.cc:145] XLA service 0x7f60a40159e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731336802.047185    2531 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2024-11-11 11:53:22.254726: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-11 11:53:24.595540: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# I0000 00:00:1731336860.949165    2531 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - loss: 2.0111 - unet3plus_output_final_activation_accuracy: 0.9481 - unet3plus_output_final_activation_recall: 0.0852 - val_loss: 1.8238 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 2/300
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_recall available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 1.4994 - unet3plus_output_final_activation_accuracy: 0.9994 - unet3plus_output_final_activation_recall: 0.0000e+00 - val_loss: 1.5402 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 3/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 1.3715 - unet3plus_output_final_activation_accuracy: 0.9994 - unet3plus_output_final_activation_recall: 2.7782e-05 - val_loss: 1.3519 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 4/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 1.2728 - unet3plus_output_final_activation_accuracy: 0.9994 - unet3plus_output_final_activation_recall: 0.0032 - val_loss: 1.2333 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 5/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 1.1904 - unet3plus_output_final_activation_accuracy: 0.9995 - unet3plus_output_final_activation_recall: 0.2297 - val_loss: 1.1499 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 6/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 1.1180 - unet3plus_output_final_activation_accuracy: 0.9996 - unet3plus_output_final_activation_recall: 0.4642 - val_loss: 1.0782 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 7/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 1.0508 - unet3plus_output_final_activation_accuracy: 0.9997 - unet3plus_output_final_activation_recall: 0.7534 - val_loss: 1.0066 - val_unet3plus_output_final_activation_accuracy: 0.9995 - val_unet3plus_output_final_activation_recall: 0.2139
# Epoch 8/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.9858 - unet3plus_output_final_activation_accuracy: 0.9997 - unet3plus_output_final_activation_recall: 0.6044 - val_loss: 0.9391 - val_unet3plus_output_final_activation_accuracy: 0.9994 - val_unet3plus_output_final_activation_recall: 0.1431
# Epoch 9/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.9185 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.8959 - val_loss: 0.8830 - val_unet3plus_output_final_activation_accuracy: 0.9994 - val_unet3plus_output_final_activation_recall: 0.1253
# Epoch 10/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.8658 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.8992 - val_loss: 0.8312 - val_unet3plus_output_final_activation_accuracy: 0.9995 - val_unet3plus_output_final_activation_recall: 0.3439
# Epoch 11/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.8138 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.8779 - val_loss: 0.7629 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.6019
# Epoch 12/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.7393 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.8668 - val_loss: 0.6709 - val_unet3plus_output_final_activation_accuracy: 0.9995 - val_unet3plus_output_final_activation_recall: 0.2519
# Epoch 13/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.6589 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.8959 - val_loss: 0.6365 - val_unet3plus_output_final_activation_accuracy: 0.9996 - val_unet3plus_output_final_activation_recall: 0.4305
# Epoch 14/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.6275 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9177 - val_loss: 0.6154 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.5329
# Epoch 15/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.6078 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9210 - val_loss: 0.5973 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.5792
# Epoch 16/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.5903 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9318 - val_loss: 0.5806 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.5833
# Epoch 17/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.5739 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9184 - val_loss: 0.5687 - val_unet3plus_output_final_activation_accuracy: 0.9988 - val_unet3plus_output_final_activation_recall: 0.8193
# Epoch 18/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.5612 - unet3plus_output_final_activation_accuracy: 0.9996 - unet3plus_output_final_activation_recall: 0.6215 - val_loss: 0.5583 - val_unet3plus_output_final_activation_accuracy: 0.9995 - val_unet3plus_output_final_activation_recall: 0.3415
# Epoch 19/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.5433 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.8303 - val_loss: 0.5329 - val_unet3plus_output_final_activation_accuracy: 0.9998 - val_unet3plus_output_final_activation_recall: 0.9280
# Epoch 20/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.5283 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9056 - val_loss: 0.5187 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.9909
# Epoch 21/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.5140 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9395 - val_loss: 0.5041 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9143
# Epoch 22/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.5001 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9408 - val_loss: 0.4905 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8743
# Epoch 23/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.4865 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9373 - val_loss: 0.4774 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8403
# Epoch 24/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.4736 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9357 - val_loss: 0.4645 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9596
# Epoch 25/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.4610 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9512 - val_loss: 0.4522 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9501
# Epoch 26/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.4488 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9523 - val_loss: 0.4403 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9635
# Epoch 27/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.4370 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9597 - val_loss: 0.4287 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9268
# Epoch 28/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.4255 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9556 - val_loss: 0.4176 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9366
# Epoch 29/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.4145 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9425 - val_loss: 0.4069 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9759
# Epoch 30/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.4037 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9564 - val_loss: 0.3962 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9462
# Epoch 31/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3932 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9568 - val_loss: 0.3861 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9760
# Epoch 32/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3832 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9610 - val_loss: 0.3762 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9253
# Epoch 33/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3734 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9594 - val_loss: 0.3667 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9330
# Epoch 34/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3639 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9596 - val_loss: 0.3573 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9501
# Epoch 35/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3547 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9575 - val_loss: 0.3484 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9786
# Epoch 36/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3457 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9631 - val_loss: 0.3396 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9497
# Epoch 37/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3371 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9615 - val_loss: 0.3312 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9493
# Epoch 38/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3287 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9601 - val_loss: 0.3229 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9572
# Epoch 39/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.3206 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9613 - val_loss: 0.3152 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8986
# Epoch 40/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.3127 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9513 - val_loss: 0.3073 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9373
# Epoch 41/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.3049 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9565 - val_loss: 0.2998 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9554
# Epoch 42/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2976 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9598 - val_loss: 0.2925 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9668
# Epoch 43/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2904 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9652 - val_loss: 0.2855 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9414
# Epoch 44/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2833 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9605 - val_loss: 0.2787 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9596
# Epoch 45/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2765 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9633 - val_loss: 0.2720 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9512
# Epoch 46/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2699 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9641 - val_loss: 0.2655 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9344
# Epoch 47/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2636 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9595 - val_loss: 0.2593 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9785
# Epoch 48/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2573 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9656 - val_loss: 0.2531 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9673
# Epoch 49/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2513 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9682 - val_loss: 0.2473 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9520
# Epoch 50/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2453 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9671 - val_loss: 0.2416 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9478
# Epoch 51/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2396 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9708 - val_loss: 0.2359 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9536
# Epoch 52/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2374 - unet3plus_output_final_activation_accuracy: 0.9997 - unet3plus_output_final_activation_recall: 0.6741 - val_loss: 0.3853 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 53/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2339 - unet3plus_output_final_activation_accuracy: 0.9994 - unet3plus_output_final_activation_recall: 7.7544e-04 - val_loss: 0.3100 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 54/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.2253 - unet3plus_output_final_activation_accuracy: 0.9995 - unet3plus_output_final_activation_recall: 0.1201 - val_loss: 0.2765 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.0000e+00
# Epoch 55/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.2192 - unet3plus_output_final_activation_accuracy: 0.9998 - unet3plus_output_final_activation_recall: 0.7849 - val_loss: 0.2356 - val_unet3plus_output_final_activation_accuracy: 0.9994 - val_unet3plus_output_final_activation_recall: 0.0714
# Epoch 56/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.2142 - unet3plus_output_final_activation_accuracy: 0.9998 - unet3plus_output_final_activation_recall: 0.8596 - val_loss: 0.2108 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9112
# Epoch 57/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.2090 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9282 - val_loss: 0.2119 - val_unet3plus_output_final_activation_accuracy: 0.9996 - val_unet3plus_output_final_activation_recall: 0.4727
# Epoch 58/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.2042 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9222 - val_loss: 0.2013 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8347
# Epoch 59/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1997 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9332 - val_loss: 0.1980 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.6454
# Epoch 60/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1950 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9280 - val_loss: 0.1928 - val_unet3plus_output_final_activation_accuracy: 0.9998 - val_unet3plus_output_final_activation_recall: 0.7936
# Epoch 61/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1907 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9453 - val_loss: 0.1882 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8577
# Epoch 62/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1864 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9489 - val_loss: 0.1841 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8671
# Epoch 63/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1824 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9549 - val_loss: 0.1801 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8449
# Epoch 64/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1785 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9481 - val_loss: 0.1759 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9101
# Epoch 65/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1745 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9554 - val_loss: 0.1721 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9211
# Epoch 66/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1708 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9579 - val_loss: 0.1684 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9168
# Epoch 67/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1672 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9574 - val_loss: 0.1649 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9007
# Epoch 68/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1635 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9614 - val_loss: 0.1613 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9220
# Epoch 69/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1601 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9576 - val_loss: 0.1578 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9358
# Epoch 70/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1565 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9633 - val_loss: 0.1546 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9788
# Epoch 71/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1532 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9633 - val_loss: 0.1513 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9477
# Epoch 72/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1501 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9614 - val_loss: 0.1481 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9398
# Epoch 73/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1469 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9616 - val_loss: 0.1450 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9479
# Epoch 74/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1437 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9585 - val_loss: 0.1420 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9380
# Epoch 75/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1408 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9587 - val_loss: 0.1391 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9358
# Epoch 76/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1379 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9629 - val_loss: 0.1362 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9518
# Epoch 77/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.1351 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9660 - val_loss: 0.1334 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9478
# Epoch 78/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1323 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9700 - val_loss: 0.1307 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9526
# Epoch 79/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 356ms/step - loss: 0.1296 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9634 - val_loss: 0.1282 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9177
# Epoch 80/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 355ms/step - loss: 0.1270 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9667 - val_loss: 0.1254 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9523
# Epoch 81/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.1242 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9627 - val_loss: 0.1232 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9512
# Epoch 82/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1218 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9654 - val_loss: 0.1205 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9423
# Epoch 83/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1193 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9647 - val_loss: 0.1182 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9143
# Epoch 84/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1169 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9689 - val_loss: 0.1157 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9559
# Epoch 85/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1146 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9688 - val_loss: 0.1134 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9527
# Epoch 86/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1123 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9680 - val_loss: 0.1112 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9748
# Epoch 87/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1102 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9718 - val_loss: 0.1090 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9493
# Epoch 88/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1081 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9657 - val_loss: 0.1068 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9555
# Epoch 89/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1059 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9717 - val_loss: 0.1048 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9711
# Epoch 90/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1039 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9700 - val_loss: 0.1028 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9595
# Epoch 91/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.1016 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9702 - val_loss: 0.1008 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9716
# Epoch 92/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0998 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9721 - val_loss: 0.0988 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9787
# Epoch 93/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0979 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9728 - val_loss: 0.0969 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9667
# Epoch 94/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0958 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9701 - val_loss: 0.0951 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9607
# Epoch 95/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0942 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9651 - val_loss: 0.1068 - val_unet3plus_output_final_activation_accuracy: 0.9989 - val_unet3plus_output_final_activation_recall: 0.3466
# Epoch 96/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0950 - unet3plus_output_final_activation_accuracy: 0.9996 - unet3plus_output_final_activation_recall: 0.2739 - val_loss: 0.1011 - val_unet3plus_output_final_activation_accuracy: 0.9993 - val_unet3plus_output_final_activation_recall: 0.2092
# Epoch 97/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0915 - unet3plus_output_final_activation_accuracy: 0.9998 - unet3plus_output_final_activation_recall: 0.8485 - val_loss: 0.0958 - val_unet3plus_output_final_activation_accuracy: 0.9996 - val_unet3plus_output_final_activation_recall: 0.4550
# Epoch 98/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0890 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9450 - val_loss: 0.0976 - val_unet3plus_output_final_activation_accuracy: 0.9995 - val_unet3plus_output_final_activation_recall: 0.2599
# Epoch 99/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0875 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9464 - val_loss: 0.0907 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.6076
# Epoch 100/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0856 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9594 - val_loss: 0.0858 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8136
# Epoch 101/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0839 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9591 - val_loss: 0.0836 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8830
# Epoch 102/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0823 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9575 - val_loss: 0.0818 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9124
# Epoch 103/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0808 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9545 - val_loss: 0.0802 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9361
# Epoch 104/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0795 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9688 - val_loss: 0.0787 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9296
# Epoch 105/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0778 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9656 - val_loss: 0.0778 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8727
# Epoch 106/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0766 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9545 - val_loss: 0.0766 - val_unet3plus_output_final_activation_accuracy: 0.9998 - val_unet3plus_output_final_activation_recall: 0.9472
# Epoch 107/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0756 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.8859 - val_loss: 0.0961 - val_unet3plus_output_final_activation_accuracy: 0.9994 - val_unet3plus_output_final_activation_recall: 0.0796
# Epoch 108/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0739 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9506 - val_loss: 0.0768 - val_unet3plus_output_final_activation_accuracy: 0.9998 - val_unet3plus_output_final_activation_recall: 0.7659
# Epoch 109/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0725 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9636 - val_loss: 0.0722 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9081
# Epoch 110/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0711 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9651 - val_loss: 0.0708 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9069
# Epoch 111/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0696 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9628 - val_loss: 0.0692 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9488
# Epoch 112/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0684 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9644 - val_loss: 0.0679 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9391
# Epoch 113/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0671 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9643 - val_loss: 0.0667 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9635
# Epoch 114/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0661 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9699 - val_loss: 0.0655 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9803
# Epoch 115/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0648 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9719 - val_loss: 0.0644 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9788
# Epoch 116/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0634 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9697 - val_loss: 0.0632 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9757
# Epoch 117/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0625 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9709 - val_loss: 0.0621 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9490
# Epoch 118/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0613 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9656 - val_loss: 0.0610 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9437
# Epoch 119/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0604 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9651 - val_loss: 0.0599 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9628
# Epoch 120/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0593 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9708 - val_loss: 0.0589 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9593
# Epoch 121/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0580 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9706 - val_loss: 0.0578 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9697
# Epoch 122/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0570 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9673 - val_loss: 0.0569 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9723
# Epoch 123/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0560 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9751 - val_loss: 0.0559 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9473
# Epoch 124/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0550 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9725 - val_loss: 0.0549 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9598
# Epoch 125/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0543 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9735 - val_loss: 0.0540 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9626
# Epoch 126/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0532 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9718 - val_loss: 0.0530 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9642
# Epoch 127/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0524 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9716 - val_loss: 0.0521 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9696
# Epoch 128/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0514 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9743 - val_loss: 0.0512 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9710
# Epoch 129/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0504 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9735 - val_loss: 0.0504 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9727
# Epoch 130/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0497 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9761 - val_loss: 0.0495 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9665
# Epoch 131/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0487 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9736 - val_loss: 0.0487 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9679
# Epoch 132/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0483 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9769 - val_loss: 0.0479 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9471
# Epoch 133/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0472 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9737 - val_loss: 0.0471 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9429
# Epoch 134/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0465 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9709 - val_loss: 0.0463 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9689
# Epoch 135/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0454 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9739 - val_loss: 0.0455 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9433
# Epoch 136/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0450 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9757 - val_loss: 0.0448 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9703
# Epoch 137/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0440 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9782 - val_loss: 0.0441 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9671
# Epoch 138/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 354ms/step - loss: 0.0433 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9758 - val_loss: 0.0434 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9867
# Epoch 139/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0425 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9752 - val_loss: 0.0429 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9616
# Epoch 140/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0420 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9723 - val_loss: 0.0621 - val_unet3plus_output_final_activation_accuracy: 0.9994 - val_unet3plus_output_final_activation_recall: 0.1509
# Epoch 141/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 355ms/step - loss: 0.0424 - unet3plus_output_final_activation_accuracy: 0.9998 - unet3plus_output_final_activation_recall: 0.8580 - val_loss: 0.0449 - val_unet3plus_output_final_activation_accuracy: 0.9997 - val_unet3plus_output_final_activation_recall: 0.7595
# Epoch 142/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0406 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9629 - val_loss: 0.0407 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9836
# Epoch 143/300
# ...
# Epoch 251/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0106 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9830 - val_loss: 0.0109 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9636
# Epoch 252/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0103 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9865 - val_loss: 0.0108 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9685
# Epoch 253/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0101 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9858 - val_loss: 0.0108 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9624
# Epoch 254/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0104 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9840 - val_loss: 0.0107 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9721
# Epoch 255/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 21s 352ms/step - loss: 0.0103 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9862 - val_loss: 0.0106 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9684
# Epoch 256/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0099 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9848 - val_loss: 0.0106 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9844
# Epoch 257/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0097 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9867 - val_loss: 0.0105 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9599
# Epoch 258/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0099 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9850 - val_loss: 0.0104 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9655
# Epoch 259/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0097 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9883 - val_loss: 0.0104 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9621
# Epoch 260/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0096 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9858 - val_loss: 0.0104 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9906
# Epoch 261/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0093 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9848 - val_loss: 0.0102 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9630
# Epoch 262/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0101 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9525 - val_loss: 0.0701 - val_unet3plus_output_final_activation_accuracy: 0.9988 - val_unet3plus_output_final_activation_recall: 0.1959
# Epoch 263/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0097 - unet3plus_output_final_activation_accuracy: 0.9999 - unet3plus_output_final_activation_recall: 0.9358 - val_loss: 0.0205 - val_unet3plus_output_final_activation_accuracy: 0.9995 - val_unet3plus_output_final_activation_recall: 0.6613
# Epoch 264/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0094 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9671 - val_loss: 0.0108 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.8899
# Epoch 265/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0093 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9756 - val_loss: 0.0101 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9724
# Epoch 266/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0093 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9815 - val_loss: 0.0099 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9505
# Epoch 267/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0094 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9810 - val_loss: 0.0099 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9507
# Epoch 268/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0093 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9833 - val_loss: 0.0099 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9649
# Epoch 269/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0092 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9826 - val_loss: 0.0098 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9584
# Epoch 270/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0090 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9835 - val_loss: 0.0098 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9504
# Epoch 271/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0090 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9867 - val_loss: 0.0097 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9478
# Epoch 272/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0085 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9840 - val_loss: 0.0096 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9652
# Epoch 273/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0089 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9873 - val_loss: 0.0096 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9794
# Epoch 274/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0087 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9871 - val_loss: 0.0095 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9630
# Epoch 275/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0090 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9845 - val_loss: 0.0095 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9477
# Epoch 276/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0089 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9828 - val_loss: 0.0094 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9631
# Epoch 277/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0086 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9878 - val_loss: 0.0094 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9660
# Epoch 278/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0088 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9890 - val_loss: 0.0094 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9487
# Epoch 279/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0086 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9861 - val_loss: 0.0093 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9552
# Epoch 280/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0082 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9897 - val_loss: 0.0093 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9725
# Epoch 281/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0084 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9912 - val_loss: 0.0092 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9826
# Epoch 282/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0081 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9902 - val_loss: 0.0092 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9593
# Epoch 283/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0082 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9913 - val_loss: 0.0091 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9752
# Epoch 284/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0084 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9930 - val_loss: 0.0091 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9697
# Epoch 285/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0083 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9906 - val_loss: 0.0091 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9570
# Epoch 286/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0084 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9915 - val_loss: 0.0090 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9741
# Epoch 287/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0084 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9913 - val_loss: 0.0090 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9793
# Epoch 288/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0083 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9928 - val_loss: 0.0090 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9656
# Epoch 289/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0086 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9913 - val_loss: 0.0089 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9750
# Epoch 290/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0082 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9940 - val_loss: 0.0089 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9564
# Epoch 291/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.0084 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9937 - val_loss: 0.0089 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9706
# Epoch 292/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0083 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9934 - val_loss: 0.0089 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9644
# Epoch 293/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0080 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9940 - val_loss: 0.0088 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9824
# Epoch 294/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 351ms/step - loss: 0.0077 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9935 - val_loss: 0.0088 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9793
# Epoch 295/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0083 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9956 - val_loss: 0.0088 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9768
# Epoch 296/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 352ms/step - loss: 0.0081 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9926 - val_loss: 0.0088 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9616
# Epoch 297/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0078 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9950 - val_loss: 0.0088 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9496
# Epoch 298/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0083 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9938 - val_loss: 0.0087 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9804
# Epoch 299/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0077 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9954 - val_loss: 0.0087 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9768
# Epoch 300/300
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 15s 353ms/step - loss: 0.0078 - unet3plus_output_final_activation_accuracy: 1.0000 - unet3plus_output_final_activation_recall: 0.9942 - val_loss: 0.0086 - val_unet3plus_output_final_activation_accuracy: 0.9999 - val_unet3plus_output_final_activation_recall: 0.9715
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 71
#      69 for i in range(0, len(X_val)):
#      70     sample_image = X_val[i]
# ---> 71     sample_mask = y_val[i].astype(np.uint8).flatten()
#      72     prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
#      73     predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
#
# KeyError: 0

# %%
print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
print("Dice: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# Accuracy: 0.9999387831914992+- 0.00019809413232295305
# Jaccard: 0.9011558089714756+- 0.12774164636291746
# Dice: 0.9401424820230551+- 0.1193303006785219
# Precision: 0.9449127284050246+- 0.12597651274237123
# Recall: 0.9426999301323349+- 0.0933804018620979

# %%
acc_mean_fold = []
jacc_mean_fold = []
f1_mean_fold = []
prec_mean_fold = []
rec_mean_fold = []

acc_std_fold = []
jacc_std_fold = []
f1_std_fold = []
prec_std_fold = []
rec_std_fold = []


f = 0
kf = KFold(n_splits=k, shuffle=True, random_state=28)
for train_ind, test_ind in tqdm(kf.split(X), total=kf.get_n_splits(), desc="k-fold"):
    X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]

    acc= []
    jacc = []
    f1 = []
    prec = []
    rec = []
    
    model = tf.keras.models.load_model('model_'+str(f+1)+'fold.h5')

    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc.append(accuracy_score(sample_mask, predicted_mask))
        jacc.append(jaccard_score(sample_mask, predicted_mask))
        f1.append(f1_score(sample_mask, predicted_mask))
        prec.append(precision_score(sample_mask, predicted_mask))
        rec.append(recall_score(sample_mask, predicted_mask))

    acc_mean_fold.append(np.mean(acc))
    acc_std_fold.append(np.std(acc))
    jacc_mean_fold.append(np.mean(jacc))
    jacc_std_fold.append(np.std(jacc))
    f1_mean_fold.append(np.mean(f1))
    f1_std_fold.append(np.std(f1))
    prec_mean_fold.append(np.mean(prec))
    prec_std_fold.append(np.std(prec))
    rec_mean_fold.append(np.mean(rec))
    rec_std_fold.append(np.std(rec))
    
    print("Model - Fold" + str(f+1)+ "Accuracy: " + str(acc_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Jaccard: " + str(jacc_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Dice: " + str(f1_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Precision: " + str(prec_mean_fold[-1]))
    print("Model - Fold" + str(f+1)+ "Recall: " + str(rec_mean_fold[-1]))

    f += 1

# %%
print("Accuracy: "+ str(np.mean(acc_mean_fold)*100) + " +- " + str(np.std(acc_std_fold)*100))
print("Jaccard: "+ str(np.mean(jacc_mean_fold)*100) + " +- " + str(np.std(jacc_std_fold)*100))
print("Dice: "+ str(np.mean(f1_mean_fold)*100) + " +- " + str(np.std(f1_std_fold)*100))
print("Precision: "+ str(np.mean(prec_mean_fold)*100) + " +- " + str(np.std(prec_std_fold)*100))
print("Recall: "+ str(np.mean(rec_mean_fold)*100) + " +- " + str(np.std(rec_std_fold)*100))

# %%
best_model = tf.keras.models.load_model('UNET3Plus 5-fold models/model_1fold.keras')

# %%
kf = KFold(n_splits=k, shuffle=True, random_state=28)
for i, (train_ind, test_ind) in enumerate(kf.split(X)):
    if i == 0:
        X_train, X_val, y_train, y_val = X[train_ind], X[test_ind], y[train_ind], y[test_ind]
        break

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input image', 'True mask', 'Predicted mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap='gray')
    plt.axis('off')
  plt.show()
  
i = random.randint(0, len(X_val))
sample_image = X_val[i]
sample_mask = y_val[i]
prediction = best_model.predict(sample_image[tf.newaxis, ...])[0]
predicted_mask = (prediction > 0.5).astype(np.uint8)
display([sample_image, sample_mask,predicted_mask])

sample_mask = y_val[i].astype(np.uint8).flatten()
predicted_mask = predicted_mask.flatten()


print("Accuracy: "+ str(accuracy_score(sample_mask, predicted_mask)))
print("Jaccard: "+ str(jaccard_score(sample_mask, predicted_mask)))
print("Dice: "+ str((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask))))
print("Precision: "+ str(precision_score(sample_mask, predicted_mask)))
print("Recall: "+ str(recall_score(sample_mask, predicted_mask)))

# %%
predicted_mask.shape
