# %% [markdown]
# # Kidney Stone Segmentation Using U-Net and Fully Convolutional Networks

# %% [markdown]
# ## Importing Libraries

# %%
import tensorflow as tf
from tensorflow.python.keras.backend import set_session
import os
import random
import numpy as np
 
from tqdm import tqdm 

from PIL import Image
import cv2
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
# Out:
# 2023-09-15 16:38:05.912416: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-15 16:38:06.278745: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-09-15 16:38:07.125659: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-09-15 16:38:07.125751: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-09-15 16:38:07.125757: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Parameters and Variable

# %%
seeds = [13, 42, 1, 83, 76]
np.random.seed = seeds[0]

num_classes = 1
split_size = 0.5


IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 1

DATA_PATH = 'data/'

data_ids = next(os.walk(DATA_PATH+'/image'))[2]

X = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
y = np.zeros((len(data_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
os.environ['TF_GPU_ALLOCATOR']= 'cuda_malloc_async'

# %% [markdown]
# ## Read Dataset

# %%
print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(data_ids), total=len(data_ids)):   
    path = DATA_PATH
    img = imread(path + '/image/' + id_)[:,:]
    img = img.reshape(img.shape[0], img.shape[1], IMG_CHANNELS)
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X[n] = img  #Fill empty X_train with values from img
    
    mask = imread(path + 'label/' + id_)
    mask = (mask >= 250)
    mask = np.expand_dims(resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                      preserve_range=True), axis=-1)
    y[n] = mask 
    #plt.axis("off")
    #imshow(y[n])
    #plt.show()
# Out:
# Resizing training images and masks
# 100%|█████████████████████████████████████████████████████████████████████████████████| 838/838 [00:25<00:00, 33.49it/s]

# %% [markdown]
# ## Sample Image and Ground-Truth Label from Dataset

# %%
image_x = random.randint(0, len(X))
plt.axis("off")
imshow(X[image_x])
plt.show()
plt.axis("off")
imshow(np.squeeze(y[image_x]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 image_x = random.randint(0, len(X))
#       2 plt.axis("off")
#       3 imshow(X[image_x])
#
# NameError: name 'random' is not defined

# %%
def unet():
    inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    
    #Contraction path
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = tf.keras.layers.Dropout(0.1)(c1)
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    b1 = tf.keras.layers.BatchNormalization()(c1)
    r1 = tf.keras.layers.ReLU()(b1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(r1)
    
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = tf.keras.layers.Dropout(0.1)(c2)
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    b2 = tf.keras.layers.BatchNormalization()(c2)
    r2 = tf.keras.layers.ReLU()(b2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(r2)
     
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = tf.keras.layers.Dropout(0.2)(c3)
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    b3 = tf.keras.layers.BatchNormalization()(c3)
    r3 = tf.keras.layers.ReLU()(b3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(r3)
     
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = tf.keras.layers.Dropout(0.2)(c4)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    b4 = tf.keras.layers.BatchNormalization()(c4)
    r4 = tf.keras.layers.ReLU()(b4)
    p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(r4)
     
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    b5 = tf.keras.layers.BatchNormalization()(c5)
    r5 = tf.keras.layers.ReLU()(b5)
    c5 = tf.keras.layers.Dropout(0.3)(r5)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    u6 = tf.keras.layers.BatchNormalization()(u6)
    u6 = tf.keras.layers.ReLU()(u6)
    
     
    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(u6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    u7 = tf.keras.layers.BatchNormalization()(u7)
    u7 = tf.keras.layers.ReLU()(u7)
    
     
    u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(u7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    u8 = tf.keras.layers.BatchNormalization()(u8)
    u8 = tf.keras.layers.ReLU()(u8)
     
    u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(u8)
    u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
    u9 = tf.keras.layers.BatchNormalization()(u9)
    u9 = tf.keras.layers.ReLU()(u9)
    
     
    outputs = tf.keras.layers.Conv2D(num_classes, (1, 1), activation='sigmoid')(u9)
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.Recall(name='recall')])

    return model

# %%
acc = []
jacc = []
f1 = []
prec = []
rec = []


for f in range(1, len(seeds)):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=split_size, random_state=seeds[f])


    model = unet()
    
    checkpoint_filepath = 'model1_' + str(f+1)+'fold.h5'
    callbacks = [
            tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
            tf.keras.callbacks.TensorBoard(log_dir='logs'),
            tf.keras.callbacks.ModelCheckpoint(
                filepath=checkpoint_filepath,
                save_weights_only=False,
                monitor='val_recall',
                mode='max',
                save_best_only=True,
                verbose=1)]
    
    model.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=16, epochs=300, callbacks=callbacks)

    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc.append(accuracy_score(sample_mask, predicted_mask))
        jacc.append(jaccard_score(sample_mask, predicted_mask))
        f1.append(f1_score(sample_mask, predicted_mask))
        prec.append(precision_score(sample_mask, predicted_mask))
        rec.append(recall_score(sample_mask, predicted_mask))

    del model 

    tf.keras.backend.clear_session()
    
    model2 = unet()
    
    checkpoint_filepath = 'model2_' + str(f+1)+'fold.h5'
    callbacks = [
            tf.keras.callbacks.EarlyStopping(patience=20, monitor='val_loss'),
            tf.keras.callbacks.TensorBoard(log_dir='logs'),
            tf.keras.callbacks.ModelCheckpoint(
                filepath=checkpoint_filepath,
                save_weights_only=False,
                monitor='val_recall',
                mode='max',
                save_best_only=True,
                verbose=1)]
    
    model2.fit(X_val, y_val, validation_data=(X_train,y_train), batch_size=16, epochs=300, callbacks=callbacks)

    for i in range(0, len(X_train)):
            sample_image = X_train[i]
            sample_mask = y_train[i].astype(np.uint8).flatten()
            prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
            predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
                
            acc.append(accuracy_score(sample_mask, predicted_mask))
            jacc.append(jaccard_score(sample_mask, predicted_mask))
            f1.append(f1_score(sample_mask, predicted_mask))
            prec.append(precision_score(sample_mask, predicted_mask))
            rec.append(recall_score(sample_mask, predicted_mask))
        
    del model2
    tf.keras.backend.clear_session()
    
print("Accuracy: "+ np.mean(acc) + "+- " + np.std(acc))
print("Jaccard: "+ np.mean(jacc) + "+- " + np.std(jacc))
print("Dice: "+ (2*np.mean(jacc))/(1+np.mean(jacc)) + "+- " + np.std(2*jacc/(1+jacc)))
print("F1 Score: "+ np.mean(f1)+ "+- " + np.std(f1))
print("Precision: "+ np.mean(prec) + "+- " + np.std(prec))
print("Recall: "+ np.mean(rec) + "+- " + np.std(rec))
# Out:
# 2023-06-26 18:20:47.690213: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:47.900260: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:47.900316: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:47.900851: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-26 18:20:47.902218: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:47.902254: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:47.902270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:48.701809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:48.702345: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:48.702360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-26 18:20:48.702391: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-26 18:20:48.702404: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-06-26 18:20:48.702409: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2023-06-26 18:20:48.702547: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9394 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# Epoch 1/300
# 2023-06-26 18:20:51.794325: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8902
# 2023-06-26 18:20:53.042830: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-06-26 18:20:55.970810: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 27/27 [==============================] - ETA: 0s - loss: 0.6054 - accuracy: 0.8112 - recall: 0.1524
# Epoch 1: val_recall improved from -inf to 0.06487, saving model to model1_2fold.h5
# 27/27 [==============================] - 20s 434ms/step - loss: 0.6054 - accuracy: 0.8112 - recall: 0.1524 - val_loss: 0.6536 - val_accuracy: 0.7952 - val_recall: 0.0649
# Epoch 2/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.4267 - accuracy: 0.9958 - recall: 1.6477e-04
# Epoch 2: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 381ms/step - loss: 0.4264 - accuracy: 0.9958 - recall: 1.6451e-04 - val_loss: 0.4604 - val_accuracy: 0.9298 - val_recall: 3.7978e-04
# Epoch 3/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.3419 - accuracy: 0.9988 - recall: 0.0000e+00
# Epoch 3: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 381ms/step - loss: 0.3417 - accuracy: 0.9988 - recall: 0.0000e+00 - val_loss: 0.3953 - val_accuracy: 0.9805 - val_recall: 2.8132e-05
# Epoch 4/300
# 27/27 [==============================] - ETA: 0s - loss: 0.2659 - accuracy: 0.9992 - recall: 0.0000e+00
# Epoch 4: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 383ms/step - loss: 0.2659 - accuracy: 0.9992 - recall: 0.0000e+00 - val_loss: 0.3339 - val_accuracy: 0.9980 - val_recall: 1.4066e-05
# Epoch 5/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.2132 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 5: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 386ms/step - loss: 0.2130 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.2820 - val_accuracy: 0.9993 - val_recall: 0.0000e+00
# Epoch 6/300
# 27/27 [==============================] - ETA: 0s - loss: 0.1730 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 6: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 384ms/step - loss: 0.1730 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.2400 - val_accuracy: 0.9993 - val_recall: 0.0000e+00
# Epoch 7/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.1405 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 7: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 383ms/step - loss: 0.1404 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.1975 - val_accuracy: 0.9993 - val_recall: 0.0000e+00
# Epoch 8/300
# 27/27 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 8: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 385ms/step - loss: 0.1124 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.1644 - val_accuracy: 0.9993 - val_recall: 0.0000e+00
# Epoch 9/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0892 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 9: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 384ms/step - loss: 0.0891 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.1271 - val_accuracy: 0.9994 - val_recall: 0.0000e+00
# Epoch 10/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0727 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 10: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0726 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.1067 - val_accuracy: 0.9994 - val_recall: 0.0000e+00
# Epoch 11/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0604 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 11: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0604 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.0884 - val_accuracy: 0.9994 - val_recall: 0.0000e+00
# Epoch 12/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0511 - accuracy: 0.9994 - recall: 0.0000e+00
# Epoch 12: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 380ms/step - loss: 0.0510 - accuracy: 0.9994 - recall: 0.0000e+00 - val_loss: 0.0778 - val_accuracy: 0.9994 - val_recall: 0.0000e+00
# Epoch 13/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0429 - accuracy: 0.9994 - recall: 0.0365
# Epoch 13: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 388ms/step - loss: 0.0429 - accuracy: 0.9994 - recall: 0.0367 - val_loss: 0.0688 - val_accuracy: 0.9994 - val_recall: 0.0000e+00
# Epoch 14/300
# 27/27 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9994 - recall: 0.1597
# Epoch 14: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s 386ms/step - loss: 0.0355 - accuracy: 0.9994 - recall: 0.1597 - val_loss: 0.0621 - val_accuracy: 0.9994 - val_recall: 0.0000e+00
# Epoch 15/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0295 - accuracy: 0.9994 - recall: 0.3199
# Epoch 15: val_recall did not improve from 0.06487
# 27/27 [==============================] - 10s
300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0054 - accuracy: 0.9999 - recall: 0.8425
# Epoch 31: val_recall did not improve from 0.22390
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0054 - accuracy: 0.9999 - recall: 0.8425 - val_loss: 0.0057 - val_accuracy: 0.9995 - val_recall: 0.1948
# Epoch 32/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0050 - accuracy: 0.9999 - recall: 0.8717
# Epoch 32: val_recall did not improve from 0.22390
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0050 - accuracy: 0.9999 - recall: 0.8709 - val_loss: 0.0052 - val_accuracy: 0.9995 - val_recall: 0.2194
# Epoch 33/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0047 - accuracy: 0.9999 - recall: 0.8634
# Epoch 33: val_recall improved from 0.22390 to 0.48017, saving model to model1_2fold.h5
# 27/27 [==============================] - 10s 388ms/step - loss: 0.0047 - accuracy: 0.9999 - recall: 0.8622 - val_loss: 0.0044 - val_accuracy: 0.9997 - val_recall: 0.4802
# Epoch 34/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0044 - accuracy: 0.9999 - recall: 0.8775
# Epoch 34: val_recall did not improve from 0.48017
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0044 - accuracy: 0.9999 - recall: 0.8774 - val_loss: 0.0049 - val_accuracy: 0.9995 - val_recall: 0.1765
# Epoch 35/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0042 - accuracy: 0.9999 - recall: 0.8547
# Epoch 35: val_recall did not improve from 0.48017
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0042 - accuracy: 0.9999 - recall: 0.8551 - val_loss: 0.0042 - val_accuracy: 0.9996 - val_recall: 0.3528
# Epoch 36/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0039 - accuracy: 0.9999 - recall: 0.8681
# Epoch 36: val_recall improved from 0.48017 to 0.78310, saving model to model1_2fold.h5
# 27/27 [==============================] - 10s 388ms/step - loss: 0.0039 - accuracy: 0.9999 - recall: 0.8680 - val_loss: 0.0034 - val_accuracy: 0.9998 - val_recall: 0.7831
# Epoch 37/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0036 - accuracy: 0.9999 - recall: 0.8916
# Epoch 37: val_recall did not improve from 0.78310
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0037 - accuracy: 0.9999 - recall: 0.8917 - val_loss: 0.0036 - val_accuracy: 0.9997 - val_recall: 0.5116
# Epoch 38/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0035 - accuracy: 0.9999 - recall: 0.8806
# Epoch 38: val_recall improved from 0.78310 to 0.80035, saving model to model1_2fold.h5
# 27/27 [==============================] - 10s 387ms/step - loss: 0.0035 - accuracy: 0.9999 - recall: 0.8791 - val_loss: 0.0031 - val_accuracy: 0.9999 - val_recall: 0.8003
# Epoch 39/300
# 27/27 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9999 - recall: 0.8874
# Epoch 39: val_recall improved from 0.80035 to 0.85796, saving model to model1_2fold.h5
# 27/27 [==============================] - 10s 388ms/step - loss: 0.0033 - accuracy: 0.9999 - recall: 0.8874 - val_loss: 0.0029 - val_accuracy: 0.9999 - val_recall: 0.8580
# Epoch 40/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0033 - accuracy: 0.9998 - recall: 0.8474
# Epoch 40: val_recall improved from 0.85796 to 0.89957, saving model to model1_2fold.h5
# 27/27 [==============================] - 10s 387ms/step - loss: 0.0033 - accuracy: 0.9998 - recall: 0.8476 - val_loss: 0.0031 - val_accuracy: 0.9998 - val_recall: 0.8996
# Epoch 41/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 0.9999 - recall: 0.8833
# Epoch 41: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 381ms/step - loss: 0.0030 - accuracy: 0.9999 - recall: 0.8836 - val_loss: 0.0027 - val_accuracy: 0.9999 - val_recall: 0.8991
# Epoch 42/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0027 - accuracy: 0.9999 - recall: 0.8920
# Epoch 42: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 384ms/step - loss: 0.0027 - accuracy: 0.9999 - recall: 0.8916 - val_loss: 0.0025 - val_accuracy: 0.9998 - val_recall: 0.7439
# Epoch 43/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.9999 - recall: 0.8945
# Epoch 43: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 381ms/step - loss: 0.0025 - accuracy: 0.9999 - recall: 0.8944 - val_loss: 0.0025 - val_accuracy: 0.9998 - val_recall: 0.6631
# Epoch 44/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0024 - accuracy: 0.9999 - recall: 0.8928
# Epoch 44: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0024 - accuracy: 0.9999 - recall: 0.8928 - val_loss: 0.0038 - val_accuracy: 0.9995 - val_recall: 0.2291
# Epoch 45/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 0.9999 - recall: 0.8776
# Epoch 45: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 384ms/step - loss: 0.0023 - accuracy: 0.9999 - recall: 0.8777 - val_loss: 0.0021 - val_accuracy: 0.9998 - val_recall: 0.7900
# Epoch 46/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0021 - accuracy: 0.9999 - recall: 0.9110
# Epoch 46: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0021 - accuracy: 0.9999 - recall: 0.9102 - val_loss: 0.0021 - val_accuracy: 0.9998 - val_recall: 0.7485
# Epoch 47/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0020 - accuracy: 0.9999 - recall: 0.9055
# Epoch 47: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0020 - accuracy: 0.9999 - recall: 0.9058 - val_loss: 0.0020 - val_accuracy: 0.9998 - val_recall: 0.7849
# Epoch 48/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 0.9999 - recall: 0.9068
# Epoch 48: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 384ms/step - loss: 0.0019 - accuracy: 0.9999 - recall: 0.9069 - val_loss: 0.0021 - val_accuracy: 0.9997 - val_recall: 0.6048
# Epoch 49/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0018 - accuracy: 0.9999 - recall: 0.9158
# Epoch 49: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0018 - accuracy: 0.9999 - recall: 0.9161 - val_loss: 0.0019 - val_accuracy: 0.9998 - val_recall: 0.7041
# Epoch 50/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 0.9999 - recall: 0.9181
# Epoch 50: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0017 - accuracy: 0.9999 - recall: 0.9036 - val_loss: 0.0017 - val_accuracy: 0.9999 - val_recall: 0.7925
# Epoch 51/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0016 - accuracy: 0.9999 - recall: 0.9230
# Epoch 51: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0016 - accuracy: 0.9999 - recall: 0.9231 - val_loss: 0.0018 - val_accuracy: 0.9998 - val_recall: 0.6946
# Epoch 52/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0015 - accuracy: 0.9999 - recall: 0.8961
# Epoch 52: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0015 - accuracy: 0.9999 - recall: 0.8944 - val_loss: 0.0014 - val_accuracy: 0.9999 - val_recall: 0.8766
# Epoch 53/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0014 - accuracy: 0.9999 - recall: 0.9270
# Epoch 53: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 382ms/step - loss: 0.0014 - accuracy: 0.9999 - recall: 0.9269 - val_loss: 0.0016 - val_accuracy: 0.9998 - val_recall: 0.8585
# Epoch 54/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0013 - accuracy: 0.9999 - recall: 0.9243
# Epoch 54: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0013 - accuracy: 0.9999 - recall: 0.9246 - val_loss: 0.0013 - val_accuracy: 0.9999 - val_recall: 0.8900
# Epoch 55/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.9999 - recall: 0.9243
# Epoch 55: val_recall did not improve from 0.89957
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0012 - accuracy: 0.9999 - recall: 0.9241 - val_loss: 0.0012 - val_accuracy: 0.9999 - val_recall: 0.8948
# Epoch 56/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0012 - accuracy: 0.9999 - recall: 0.9293
# Epoch 56: val_recall improved from 0.89957 to 0.91068, saving model to model1_2fold.h5
# 27/27 [==============================] - 10s 387ms/step - loss: 0.0012 - accuracy: 0.9999 - recall: 0.9295 - val_loss: 0.0011 - val_accuracy: 0.9999 - val_recall: 0.9107
# Epoch 57/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999 - recall: 0.9289
# Epoch 57: val_recall did not improve from 0.91068
# 27/27 [==============================] - 10s 384ms/step - loss: 0.0011 - accuracy: 0.9999 - recall: 0.9290 - val_loss: 0.0012 - val_accuracy: 0.9999 - val_recall: 0.8182
# Epoch 58/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999 - recall: 0.9240
# Epoch 58: val_recall did not improve from 0.91068
# 27/27 [==============================] - 10s 383ms/step - loss: 0.0011 - accuracy: 0.9999 - recall: 0.9241 - val_loss: 0.0012 - val_accuracy: 0.9999 - val_recall: 0.8224
# Epoch 59/300
# 26/27 [===========================>..] - ETA: 0s - loss: 0.0010 - accuracy: 0.9
300
# 26/27 [===========================>..] - ETA: 0s - loss: 4.1296e-04 - accuracy: 1.0000 - recall: 0.9523
# Epoch 90: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 4.1384e-04 - accuracy: 1.0000 - recall: 0.9524 - val_loss: 4.8077e-04 - val_accuracy: 0.9999 - val_recall: 0.8804
# Epoch 91/300
# 26/27 [===========================>..] - ETA: 0s - loss: 4.0663e-04 - accuracy: 0.9999 - recall: 0.9506
# Epoch 91: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 4.0645e-04 - accuracy: 0.9999 - recall: 0.9506 - val_loss: 5.2995e-04 - val_accuracy: 0.9999 - val_recall: 0.8561
# Epoch 92/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.8917e-04 - accuracy: 1.0000 - recall: 0.9545
# Epoch 92: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 3.8970e-04 - accuracy: 1.0000 - recall: 0.9544 - val_loss: 4.5203e-04 - val_accuracy: 0.9999 - val_recall: 0.8876
# Epoch 93/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.7998e-04 - accuracy: 1.0000 - recall: 0.9572
# Epoch 93: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 3.7957e-04 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 4.3307e-04 - val_accuracy: 0.9999 - val_recall: 0.8980
# Epoch 94/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.7537e-04 - accuracy: 1.0000 - recall: 0.9531
# Epoch 94: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 3.7515e-04 - accuracy: 1.0000 - recall: 0.9533 - val_loss: 4.5536e-04 - val_accuracy: 0.9999 - val_recall: 0.8790
# Epoch 95/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.6250e-04 - accuracy: 1.0000 - recall: 0.9574
# Epoch 95: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 383ms/step - loss: 3.6259e-04 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 3.9798e-04 - val_accuracy: 0.9999 - val_recall: 0.9081
# Epoch 96/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.5854e-04 - accuracy: 1.0000 - recall: 0.9560
# Epoch 96: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 3.5779e-04 - accuracy: 1.0000 - recall: 0.9559 - val_loss: 4.1559e-04 - val_accuracy: 0.9999 - val_recall: 0.8966
# Epoch 97/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.4765e-04 - accuracy: 1.0000 - recall: 0.9560
# Epoch 97: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 3.4758e-04 - accuracy: 1.0000 - recall: 0.9561 - val_loss: 4.7578e-04 - val_accuracy: 0.9999 - val_recall: 0.8668
# Epoch 98/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.3928e-04 - accuracy: 1.0000 - recall: 0.9578
# Epoch 98: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 3.3996e-04 - accuracy: 1.0000 - recall: 0.9573 - val_loss: 4.5011e-04 - val_accuracy: 0.9999 - val_recall: 0.8749
# Epoch 99/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.3405e-04 - accuracy: 1.0000 - recall: 0.9592
# Epoch 99: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 3.3353e-04 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 3.7050e-04 - val_accuracy: 0.9999 - val_recall: 0.9089
# Epoch 100/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.2610e-04 - accuracy: 1.0000 - recall: 0.9572
# Epoch 100: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 3.2650e-04 - accuracy: 1.0000 - recall: 0.9571 - val_loss: 3.8585e-04 - val_accuracy: 0.9999 - val_recall: 0.8997
# Epoch 101/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.1935e-04 - accuracy: 1.0000 - recall: 0.9589
# Epoch 101: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 380ms/step - loss: 3.1933e-04 - accuracy: 1.0000 - recall: 0.9590 - val_loss: 3.5994e-04 - val_accuracy: 0.9999 - val_recall: 0.9125
# Epoch 102/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.1155e-04 - accuracy: 1.0000 - recall: 0.9598
# Epoch 102: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 3.1400e-04 - accuracy: 1.0000 - recall: 0.9582 - val_loss: 3.2754e-04 - val_accuracy: 0.9999 - val_recall: 0.9331
# Epoch 103/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.1702e-04 - accuracy: 1.0000 - recall: 0.9589
# Epoch 103: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 3.1672e-04 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 3.4507e-04 - val_accuracy: 0.9999 - val_recall: 0.9161
# Epoch 104/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.0845e-04 - accuracy: 1.0000 - recall: 0.9560
# Epoch 104: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 3.0880e-04 - accuracy: 1.0000 - recall: 0.9562 - val_loss: 3.1342e-04 - val_accuracy: 1.0000 - val_recall: 0.9607
# Epoch 105/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.0158e-04 - accuracy: 1.0000 - recall: 0.9579
# Epoch 105: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 3.0146e-04 - accuracy: 1.0000 - recall: 0.9581 - val_loss: 3.5111e-04 - val_accuracy: 0.9999 - val_recall: 0.9038
# Epoch 106/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.8676e-04 - accuracy: 1.0000 - recall: 0.9616
# Epoch 106: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.8676e-04 - accuracy: 1.0000 - recall: 0.9616 - val_loss: 3.6450e-04 - val_accuracy: 0.9999 - val_recall: 0.8970
# Epoch 107/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.8083e-04 - accuracy: 1.0000 - recall: 0.9621
# Epoch 107: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.8107e-04 - accuracy: 1.0000 - recall: 0.9621 - val_loss: 3.6124e-04 - val_accuracy: 0.9999 - val_recall: 0.8966
# Epoch 108/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.7365e-04 - accuracy: 1.0000 - recall: 0.9646
# Epoch 108: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.7350e-04 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 3.7865e-04 - val_accuracy: 0.9999 - val_recall: 0.8869
# Epoch 109/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.7083e-04 - accuracy: 1.0000 - recall: 0.9606
# Epoch 109: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.7131e-04 - accuracy: 1.0000 - recall: 0.9603 - val_loss: 3.0923e-04 - val_accuracy: 0.9999 - val_recall: 0.9259
# Epoch 110/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.6493e-04 - accuracy: 1.0000 - recall: 0.9652
# Epoch 110: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.6496e-04 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 3.0533e-04 - val_accuracy: 0.9999 - val_recall: 0.9282
# Epoch 111/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.5776e-04 - accuracy: 1.0000 - recall: 0.9638
# Epoch 111: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.5761e-04 - accuracy: 1.0000 - recall: 0.9638 - val_loss: 3.4156e-04 - val_accuracy: 0.9999 - val_recall: 0.8992
# Epoch 112/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.5113e-04 - accuracy: 1.0000 - recall: 0.9652
# Epoch 112: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.5088e-04 - accuracy: 1.0000 - recall: 0.9653 - val_loss: 3.6885e-04 - val_accuracy: 0.9999 - val_recall: 0.8858
# Epoch 113/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.5555e-04 - accuracy: 1.0000 - recall: 0.9605
# Epoch 113: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.5557e-04 - accuracy: 1.0000 - recall: 0.9606 - val_loss: 4.1023e-04 - val_accuracy: 0.9999 - val_recall: 0.8603
# Epoch 114/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.4178e-04 - accuracy: 1.0000 - recall: 0.9639
# Epoch 114: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 2.4190e-04 - accuracy: 1.0000 - recall: 0.9640 - val_loss: 2.8949e-04 - val_accuracy: 0.9999 - val_recall: 0.9283
# Epoch 115/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.3707e-04 - accuracy: 1.0000 - recall: 0.9648
# Epoch 115: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.3695e-04 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 3.8363e-04 - val_accuracy: 0.9999 - val_recall: 0.8704
# Epoch 116/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.3186e-04 - accuracy: 1.0000 - recall: 0.9646
# Epoch 116: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.3178e-04 - accuracy: 1.0000 - recall: 0.9647 - val_loss: 3.7629e-04 - val_accuracy: 0.9999 - val_recall: 0.8712
# Epoch 117/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2449e-04 - accuracy: 1.0000 - recall: 0.9661
# Epoch 117: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.2427e-04 - accuracy: 1.0000 - recall: 0.9662 - val_loss: 3.4852e-04 - val_accuracy: 0.9999 - val_recall: 0.8821
# Epoch 118/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.1930e-04 - accuracy: 1.0000 - recall: 0.9667
# Epoch 118: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.1920e-04 - accuracy: 1.0000 - recall: 0.9667 - val_loss: 3.8660e-04 - val_accuracy: 0.9999 - val_recall: 0.8652
# Epoch 119/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.1330e-04 - accuracy: 1.0000 - recall: 0.9644
# Epoch 119: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 380ms/step - loss: 2.1642e-04 - accuracy: 1.0000 - recall: 0.9628 - val_loss: 2.6244e-04 - val_accuracy: 0.9999 - val_recall: 0.9296
# Epoch 120/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2428e-04 - accuracy: 1.0000 - recall: 0.9661
# Epoch 120: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 2.2435e-04 - accuracy: 1.0000 - recall: 0.9661 - val_loss: 3.3738e-04 - val_accuracy: 0.9999 - val_recall: 0.9100
# Epoch 121/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2169e-04 - accuracy: 1.0000 - recall: 0.9610
# Epoch 121: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.2157e-04 - accuracy: 1.0000 - recall: 0.9610 - val_loss: 2.7996e-04 - val_accuracy: 0.9999 - val_recall: 0.9143
# Epoch 122/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.4205e-04 - accuracy: 1.0000 - recall: 0.9569
# Epoch 122: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.4170e-04 - accuracy: 1.0000 - recall: 0.9570 - val_loss: 3.6679e-04 - val_accuracy: 0.9999 - val_recall: 0.8969
# Epoch 123/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2490e-04 - accuracy: 1.0000 - recall: 0.9602
# Epoch 123: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 2.2505e-04 - accuracy: 1.0000 - recall: 0.9601 - val_loss: 2.5193e-04 - val_accuracy: 0.9999 - val_recall: 0.9303
# Epoch 124/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.0688e-04 - accuracy: 1.0000 - recall: 0.9645
# Epoch 124: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.0639e-04 - accuracy: 1.0000 - recall: 0.9645 - val_loss: 2.6171e-04 - val_accuracy: 0.9999 - val_recall: 0.9201
# Epoch 125/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.0184e-04 - accuracy: 1.0000 - recall: 0.9651
# Epoch 125: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 2.0205e-04 - accuracy: 1.0000 - recall: 0.9651 - val_loss: 3.0506e-04 - val_accuracy: 0.9999 - val_recall: 0.8951
# Epoch 126/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.9368e-04 - accuracy: 1.0000 - recall: 0.9691
# Epoch 126: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 1.9387e-04 - accuracy: 1.0000 - recall: 0.9690 - val_loss: 2.5156e-04 - val_accuracy: 0.9999 - val_recall: 0.9243
# Epoch 127/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.8836e-04 - accuracy: 1.0000 - recall: 0.9685
# Epoch 127: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 381ms/step - loss: 1.8829e-04 - accuracy: 1.0000 - recall: 0.9686 - val_loss: 2.7215e-04 - val_accuracy: 0.9999 - val_recall: 0.9105
# Epoch 128/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.8832e-04 - accuracy: 1.0000 - recall: 0.9660
# Epoch 128: val_recall did not improve from 0.97717
# 27/27 [==============================] - 10s 382ms/step - loss: 1.8826e-04 - accuracy: 1.0000 - recall: 0.9661 - val_loss: 2.7769e-04 - val_accuracy: 0.9999 - val_recall: 0.9065
# Epoch 129/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.8095e-04 - accuracy: 1.0000 - recall: 0.9677
# Epoch 129: val_recall did not improve from 0.97717
# ...
# Epoch 117: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 386ms/step - loss: 3.6260e-04 - accuracy: 0.9999 - recall: 0.9566 - val_loss: 3.7652e-04 - val_accuracy: 0.9999 - val_recall: 0.9201
# Epoch 118/300
# 27/27 [==============================] - ETA: 0s - loss: 3.6793e-04 - accuracy: 0.9999 - recall: 0.9469
# Epoch 118: val_recall did not improve from 0.99605
# 27/27 [==============================] - 155s 6s/step - loss: 3.6793e-04 - accuracy: 0.9999 - recall: 0.9469 - val_loss: 3.5541e-04 - val_accuracy: 0.9999 - val_recall: 0.9303
# Epoch 119/300
# 27/27 [==============================] - ETA: 0s - loss: 3.1950e-04 - accuracy: 1.0000 - recall: 0.9581
# Epoch 119: val_recall did not improve from 0.99605
# 27/27 [==============================] - 13s 458ms/step - loss: 3.1950e-04 - accuracy: 1.0000 - recall: 0.9581 - val_loss: 3.1741e-04 - val_accuracy: 0.9999 - val_recall: 0.9195
# Epoch 120/300
# 27/27 [==============================] - ETA: 0s - loss: 3.1417e-04 - accuracy: 1.0000 - recall: 0.9608
# Epoch 120: val_recall did not improve from 0.99605
# 27/27 [==============================] - 4185s 161s/step - loss: 3.1417e-04 - accuracy: 1.0000 - recall: 0.9608 - val_loss: 3.2434e-04 - val_accuracy: 0.9999 - val_recall: 0.9264
# Epoch 121/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.0078e-04 - accuracy: 1.0000 - recall: 0.9603
# Epoch 121: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 387ms/step - loss: 3.0064e-04 - accuracy: 1.0000 - recall: 0.9604 - val_loss: 3.3407e-04 - val_accuracy: 0.9999 - val_recall: 0.9239
# Epoch 122/300
# 27/27 [==============================] - ETA: 0s - loss: 2.9608e-04 - accuracy: 1.0000 - recall: 0.9632
# Epoch 122: val_recall did not improve from 0.99605
# 27/27 [==============================] - 21s 810ms/step - loss: 2.9608e-04 - accuracy: 1.0000 - recall: 0.9632 - val_loss: 3.2678e-04 - val_accuracy: 0.9999 - val_recall: 0.8919
# Epoch 123/300
# 27/27 [==============================] - ETA: 0s - loss: 3.2465e-04 - accuracy: 0.9999 - recall: 0.9525
# Epoch 123: val_recall did not improve from 0.99605
# 27/27 [==============================] - 11s 387ms/step - loss: 3.2465e-04 - accuracy: 0.9999 - recall: 0.9525 - val_loss: 2.6525e-04 - val_accuracy: 1.0000 - val_recall: 0.9474
# Epoch 124/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.9608e-04 - accuracy: 1.0000 - recall: 0.9566
# Epoch 124: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 2.9576e-04 - accuracy: 1.0000 - recall: 0.9566 - val_loss: 3.2020e-04 - val_accuracy: 0.9999 - val_recall: 0.8985
# Epoch 125/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.2182e-04 - accuracy: 0.9999 - recall: 0.9584
# Epoch 125: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 3.2098e-04 - accuracy: 0.9999 - recall: 0.9586 - val_loss: 2.8177e-04 - val_accuracy: 0.9999 - val_recall: 0.9303
# Epoch 126/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.0927e-04 - accuracy: 0.9999 - recall: 0.9567
# Epoch 126: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 3.0855e-04 - accuracy: 0.9999 - recall: 0.9566 - val_loss: 3.1332e-04 - val_accuracy: 0.9999 - val_recall: 0.9085
# Epoch 127/300
# 27/27 [==============================] - ETA: 0s - loss: 2.9144e-04 - accuracy: 1.0000 - recall: 0.9641
# Epoch 127: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 2.9144e-04 - accuracy: 1.0000 - recall: 0.9641 - val_loss: 2.7804e-04 - val_accuracy: 1.0000 - val_recall: 0.9287
# Epoch 128/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.8409e-04 - accuracy: 1.0000 - recall: 0.9620
# Epoch 128: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 2.8471e-04 - accuracy: 1.0000 - recall: 0.9619 - val_loss: 2.6023e-04 - val_accuracy: 1.0000 - val_recall: 0.9626
# Epoch 129/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.7090e-04 - accuracy: 0.9999 - recall: 0.9353
# Epoch 129: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 3.7053e-04 - accuracy: 0.9999 - recall: 0.9354 - val_loss: 4.3393e-04 - val_accuracy: 0.9999 - val_recall: 0.9788
# Epoch 130/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.2891e-04 - accuracy: 0.9999 - recall: 0.9475
# Epoch 130: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 3.3210e-04 - accuracy: 0.9999 - recall: 0.9476 - val_loss: 2.8587e-04 - val_accuracy: 0.9999 - val_recall: 0.9726
# Epoch 131/300
# 26/27 [===========================>..] - ETA: 0s - loss: 3.4742e-04 - accuracy: 0.9999 - recall: 0.9439
# Epoch 131: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 3.4692e-04 - accuracy: 0.9999 - recall: 0.9440 - val_loss: 2.6900e-04 - val_accuracy: 1.0000 - val_recall: 0.9525
# Epoch 132/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.8050e-04 - accuracy: 1.0000 - recall: 0.9592
# Epoch 132: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 384ms/step - loss: 2.8015e-04 - accuracy: 1.0000 - recall: 0.9592 - val_loss: 2.8800e-04 - val_accuracy: 1.0000 - val_recall: 0.9509
# Epoch 133/300
# 27/27 [==============================] - ETA: 0s - loss: 2.5494e-04 - accuracy: 1.0000 - recall: 0.9632
# Epoch 133: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 387ms/step - loss: 2.5494e-04 - accuracy: 1.0000 - recall: 0.9632 - val_loss: 2.3745e-04 - val_accuracy: 1.0000 - val_recall: 0.9615
# Epoch 134/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.6151e-04 - accuracy: 1.0000 - recall: 0.9622
# Epoch 134: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.6160e-04 - accuracy: 1.0000 - recall: 0.9623 - val_loss: 2.4455e-04 - val_accuracy: 1.0000 - val_recall: 0.9411
# Epoch 135/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.5236e-04 - accuracy: 1.0000 - recall: 0.9597
# Epoch 135: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.5208e-04 - accuracy: 1.0000 - recall: 0.9600 - val_loss: 3.0232e-04 - val_accuracy: 0.9999 - val_recall: 0.8882
# Epoch 136/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.9403e-04 - accuracy: 1.0000 - recall: 0.9591
# Epoch 136: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 2.9418e-04 - accuracy: 1.0000 - recall: 0.9591 - val_loss: 2.1059e-04 - val_accuracy: 1.0000 - val_recall: 0.9679
# Epoch 137/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.8971e-04 - accuracy: 1.0000 - recall: 0.9598
# Epoch 137: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.8913e-04 - accuracy: 1.0000 - recall: 0.9598 - val_loss: 7.4345e-04 - val_accuracy: 0.9998 - val_recall: 0.6227
# Epoch 138/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.8801e-04 - accuracy: 0.9999 - recall: 0.9565
# Epoch 138: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 383ms/step - loss: 2.8904e-04 - accuracy: 0.9999 - recall: 0.9561 - val_loss: 2.3942e-04 - val_accuracy: 1.0000 - val_recall: 0.9875
# Epoch 139/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.5516e-04 - accuracy: 1.0000 - recall: 0.9610
# Epoch 139: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.5483e-04 - accuracy: 1.0000 - recall: 0.9611 - val_loss: 2.3136e-04 - val_accuracy: 1.0000 - val_recall: 0.9722
# Epoch 140/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.3472e-04 - accuracy: 1.0000 - recall: 0.9657
# Epoch 140: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.3431e-04 - accuracy: 1.0000 - recall: 0.9657 - val_loss: 2.4330e-04 - val_accuracy: 1.0000 - val_recall: 0.9357
# Epoch 141/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2660e-04 - accuracy: 1.0000 - recall: 0.9657
# Epoch 141: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.2623e-04 - accuracy: 1.0000 - recall: 0.9655 - val_loss: 2.7275e-04 - val_accuracy: 0.9999 - val_recall: 0.9027
# Epoch 142/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2011e-04 - accuracy: 1.0000 - recall: 0.9694
# Epoch 142: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 383ms/step - loss: 2.1991e-04 - accuracy: 1.0000 - recall: 0.9694 - val_loss: 2.5431e-04 - val_accuracy: 0.9999 - val_recall: 0.9241
# Epoch 143/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2268e-04 - accuracy: 1.0000 - recall: 0.9618
# Epoch 143: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 386ms/step - loss: 2.2269e-04 - accuracy: 1.0000 - recall: 0.9620 - val_loss: 2.2426e-04 - val_accuracy: 1.0000 - val_recall: 0.9652
# Epoch 144/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2203e-04 - accuracy: 1.0000 - recall: 0.9675
# Epoch 144: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.2524e-04 - accuracy: 1.0000 - recall: 0.9660 - val_loss: 2.2391e-04 - val_accuracy: 1.0000 - val_recall: 0.9404
# Epoch 145/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.2396e-04 - accuracy: 1.0000 - recall: 0.9692
# Epoch 145: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 2.2416e-04 - accuracy: 1.0000 - recall: 0.9690 - val_loss: 3.1548e-04 - val_accuracy: 0.9999 - val_recall: 0.9069
# Epoch 146/300
# 26/27 [===========================>..] - ETA: 0s - loss: 2.1242e-04 - accuracy: 1.0000 - recall: 0.9666
# Epoch 146: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 384ms/step - loss: 2.1244e-04 - accuracy: 1.0000 - recall: 0.9667 - val_loss: 2.0881e-04 - val_accuracy: 1.0000 - val_recall: 0.9800
# Epoch 147/300
# 27/27 [==============================] - ETA: 0s - loss: 2.0973e-04 - accuracy: 1.0000 - recall: 0.9688
# Epoch 147: val_recall did not improve from 0.99605
# 27/27 [==============================] - 13s 482ms/step - loss: 2.0973e-04 - accuracy: 1.0000 - recall: 0.9688 - val_loss: 2.6790e-04 - val_accuracy: 0.9999 - val_recall: 0.9081
# Epoch 148/300
# 27/27 [==============================] - ETA: 0s - loss: 2.2699e-04 - accuracy: 1.0000 - recall: 0.9605
# Epoch 148: val_recall did not improve from 0.99605
# 27/27 [==============================] - 29s 1s/step - loss: 2.2699e-04 - accuracy: 1.0000 - recall: 0.9605 - val_loss: 2.0712e-04 - val_accuracy: 1.0000 - val_recall: 0.9408
# Epoch 149/300
# 27/27 [==============================] - ETA: 0s - loss: 2.0931e-04 - accuracy: 1.0000 - recall: 0.9649
# Epoch 149: val_recall did not improve from 0.99605
# 27/27 [==============================] - 63s 2s/step - loss: 2.0931e-04 - accuracy: 1.0000 - recall: 0.9649 - val_loss: 2.1696e-04 - val_accuracy: 1.0000 - val_recall: 0.9713
# Epoch 150/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.9406e-04 - accuracy: 1.0000 - recall: 0.9696
# Epoch 150: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 385ms/step - loss: 1.9442e-04 - accuracy: 1.0000 - recall: 0.9697 - val_loss: 2.2417e-04 - val_accuracy: 1.0000 - val_recall: 0.9710
# Epoch 151/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.9734e-04 - accuracy: 1.0000 - recall: 0.9648
# Epoch 151: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 1.9727e-04 - accuracy: 1.0000 - recall: 0.9649 - val_loss: 2.1569e-04 - val_accuracy: 1.0000 - val_recall: 0.9603
# Epoch 152/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.8589e-04 - accuracy: 1.0000 - recall: 0.9692
# Epoch 152: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 1.8602e-04 - accuracy: 1.0000 - recall: 0.9692 - val_loss: 2.1738e-04 - val_accuracy: 1.0000 - val_recall: 0.9584
# Epoch 153/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.8011e-04 - accuracy: 1.0000 - recall: 0.9718
# Epoch 153: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 1.8021e-04 - accuracy: 1.0000 - recall: 0.9717 - val_loss: 2.2030e-04 - val_accuracy: 1.0000 - val_recall: 0.9669
# Epoch 154/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.7479e-04 - accuracy: 1.0000 - recall: 0.9731
# Epoch 154: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 1.7447e-04 - accuracy: 1.0000 - recall: 0.9731 - val_loss: 2.6926e-04 - val_accuracy: 0.9999 - val_recall: 0.9028
# Epoch 155/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.7689e-04 - accuracy: 1.0000 - recall: 0.9708
# Epoch 155: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 380ms/step - loss: 1.7726e-04 - accuracy: 1.0000 - recall: 0.9709 - val_loss: 2.0668e-04 - val_accuracy: 1.0000 - val_recall: 0.9558
# Epoch 156/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.7915e-04 - accuracy: 1.0000 - recall: 0.9673
# Epoch 156: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 1.7895e-04 - accuracy: 1.0000 - recall: 0.9674 - val_loss: 2.0257e-04 - val_accuracy: 1.0000 - val_recall: 0.9467
# Epoch 157/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.7320e-04 - accuracy: 1.0000 - recall: 0.9724
# Epoch 157: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 1.7299e-04 - accuracy: 1.0000 - recall: 0.9725 - val_loss: 1.9765e-04 - val_accuracy: 1.0000 - val_recall: 0.9569
# Epoch 158/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.6759e-04 - accuracy: 1.0000 - recall: 0.9732
# Epoch 158: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 382ms/step - loss: 1.6730e-04 - accuracy: 1.0000 - recall: 0.9732 - val_loss: 2.0184e-04 - val_accuracy: 1.0000 - val_recall: 0.9599
# Epoch 159/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.6044e-04 - accuracy: 1.0000 - recall: 0.9748
# Epoch 159: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 383ms/step - loss: 1.6112e-04 - accuracy: 1.0000 - recall: 0.9744 - val_loss: 2.2193e-04 - val_accuracy: 1.0000 - val_recall: 0.9309
# Epoch 160/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.6723e-04 - accuracy: 1.0000 - recall: 0.9720
# Epoch 160: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 1.6720e-04 - accuracy: 1.0000 - recall: 0.9718 - val_loss: 2.1161e-04 - val_accuracy: 1.0000 - val_recall: 0.9435
# Epoch 161/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.6073e-04 - accuracy: 1.0000 - recall: 0.9746
# Epoch 161: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 1.6101e-04 - accuracy: 1.0000 - recall: 0.9746 - val_loss: 2.0796e-04 - val_accuracy: 1.0000 - val_recall: 0.9445
# Epoch 162/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.5313e-04 - accuracy: 1.0000 - recall: 0.9750
# Epoch 162: val_recall did not improve from 0.99605
# 27/27 [==============================] - 10s 381ms/step - loss: 1.5321e-04 - accuracy: 1.0000 - recall: 0.9748 - val_loss: 2.1029e-04 - val_accuracy: 1.0000 - val_recall: 0.9442
# Epoch 163/300
# 26/27 [===========================>..] - ETA: 0s - loss: 1.5101e-04 - accuracy: 1.0000 - recall: 0.9769

# %%
loss = model.history.history['loss']
val_loss = model.history.history['val_loss']

plt.figure()
plt.plot( loss, 'r', label='Training loss')
plt.plot( val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.ylim([0, 1])
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 loss = model.history.history['loss']
#       2 val_loss = model.history.history['val_loss']
#       4 plt.figure()
#
# AttributeError: 'NoneType' object has no attribute 'history'

# %%
model = tf.keras.models.load_model('model_20_06_2023.h5')

# %%
model.evaluate(X_val, y_val)
# Out:
# 14/14 [==============================] - 5s 174ms/step - loss: 5.9085e-04 - accuracy: 0.9998 - recall: 0.9980
# [0.0005908514722250402, 0.9998277425765991, 0.9980053901672363]

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input image', 'True mask', 'Predicted mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap='gray')
    plt.axis('off')
  plt.show()
  
i = random.randint(0, len(X_val))
sample_image = X_val[i]
sample_mask = y_val[i]
prediction = model.predict(sample_image[tf.newaxis, ...])[0]
predicted_mask = (prediction > 0.5).astype(np.uint8)
display([sample_image, sample_mask,predicted_mask])
# Out:
# 1/1 [==============================] - 0s 145ms/step

# %% [markdown]
# Acuraccy:  0.9998064804077148
# Jaccard:  0.7504550150031974
# F1 Score:  0.8574399325558522
# Precision:  0.9923892538866844
# Recall:  0.7547991292301603

# %%
acc_mean_fold = []
jacc_mean_fold = []
dice_mean_fold = []
f1_mean_fold = []
prec_mean_fold = []
rec_mean_fold = []

acc_std_fold = []
jacc_std_fold = []
dice_std_fold = []
f1_std_fold = []
prec_std_fold = []
rec_std_fold = []



for f in range(0, len(seeds)):
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=split_size, random_state=seeds[f])

    acc= []
    jacc = []
    dice = []
    f1 = []
    prec = []
    rec = []
    
    model = tf.keras.models.load_model('model1_'+str(f+1)+'fold.h5')

    for i in range(0, len(X_val)):
        sample_image = X_val[i]
        sample_mask = y_val[i].astype(np.uint8).flatten()
        prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
        predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
            
        acc.append(accuracy_score(sample_mask, predicted_mask))
        jacc.append(jaccard_score(sample_mask, predicted_mask))
        dice.append((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask)))
        f1.append(f1_score(sample_mask, predicted_mask))
        prec.append(precision_score(sample_mask, predicted_mask))
        rec.append(recall_score(sample_mask, predicted_mask))

    acc_mean_fold.append(np.mean(acc))
    acc_std_fold.append(np.std(acc))
    jacc_mean_fold.append(np.mean(jacc))
    jacc_std_fold.append(np.std(jacc))
    dice_mean_fold.append(np.mean(dice))
    dice_std_fold.append(np.std(dice))
    f1_mean_fold.append(np.mean(f1))
    f1_std_fold.append(np.std(f1))
    prec_mean_fold.append(np.mean(prec))
    prec_std_fold.append(np.std(prec))
    rec_mean_fold.append(np.mean(rec))
    rec_std_fold.append(np.std(rec))
    
    print("Model1 - Fold" + str(f+1)+ "Accuracy: " + str(acc_mean_fold[-1]))
    print("Model1 - Fold" + str(f+1)+ "Jaccard: " + str(jacc_mean_fold[-1]))
    print("Model1 - Fold" + str(f+1)+ "Dice: " + str(dice_mean_fold[-1]))
    print("Model1 - Fold" + str(f+1)+ "F1-Score: " + str(f1_mean_fold[-1]))
    print("Model1 - Fold" + str(f+1)+ "Precision: " + str(prec_mean_fold[-1]))
    print("Model1 - Fold" + str(f+1)+ "Recall: " + str(rec_mean_fold[-1]))

    acc= []
    jacc = []
    dice = []
    f1 = []
    prec = []
    rec = []
    
    model2 = tf.keras.models.load_model('model2_'+str(f+1)+'fold.h5')
    

    for i in range(0, len(X_train)):
            sample_image = X_train[i]
            sample_mask = y_train[i].astype(np.uint8).flatten()
            prediction = model.predict(sample_image[tf.newaxis, ...],verbose=0)[0]
            predicted_mask = (prediction > 0.5).astype(np.uint8).flatten()
                
            acc.append(accuracy_score(sample_mask, predicted_mask))
            jacc.append(jaccard_score(sample_mask, predicted_mask))
            dice.append((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask)))
            f1.append(f1_score(sample_mask, predicted_mask))
            prec.append(precision_score(sample_mask, predicted_mask))
            rec.append(recall_score(sample_mask, predicted_mask))

    acc_mean_fold.append(np.mean(acc))
    acc_std_fold.append(np.std(acc))
    jacc_mean_fold.append(np.mean(jacc))
    jacc_std_fold.append(np.std(jacc))
    dice_mean_fold.append(np.mean(dice))
    dice_std_fold.append(np.std(dice))
    f1_mean_fold.append(np.mean(f1))
    f1_std_fold.append(np.std(f1))
    prec_mean_fold.append(np.mean(prec))
    prec_std_fold.append(np.std(prec))
    rec_mean_fold.append(np.mean(rec))
    rec_std_fold.append(np.std(rec))
    
    print("Model2 - Fold" + str(f+1)+ "Accuracy: " + str(acc_mean_fold[-1]))
    print("Model2 - Fold" + str(f+1)+ "Jaccard: " + str(jacc_mean_fold[-1]))
    print("Model2 - Fold" + str(f+1)+ "Dice: " + str(dice_mean_fold[-1]))
    print("Model2 - Fold" + str(f+1)+ "F1-Score: " + str(f1_mean_fold[-1]))
    print("Model2 - Fold" + str(f+1)+ "Precision: " + str(prec_mean_fold[-1]))
    print("Model2 - Fold" + str(f+1)+ "Recall: " + str(rec_mean_fold[-1]))
        
  
#print("Accuracy: "+ str(np.mean(acc)) + "+- " + str(np.std(acc)))
#print("Jaccard: "+ str(np.mean(jacc)) + "+- " + str(np.std(jacc)))
#print("Dice: "+ str((2*np.mean(jacc))/(1+np.mean(jacc))) + "+- " + str(np.std(2*jacc/(1+jacc))))
#print("F1 Score: "+ str(np.mean(f1)) + "+- " + str(np.std(f1)))
#print("Precision: "+ str(np.mean(prec)) + "+- " + str(np.std(prec)))
#print("Recall: "+ str(np.mean(rec)) + "+- " + str(np.std(rec)))
# Out:
# 2023-06-28 13:53:22.069048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:22.296117: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:22.296166: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:22.297791: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-28 13:53:22.298976: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:22.299017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:22.299036: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:23.189161: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:23.189679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:23.189691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-06-28 13:53:23.189724: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-06-28 13:53:23.189737: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-06-28 13:53:23.189743: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2023-06-28 13:53:23.189901: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9394 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2023-06-28 13:53:25.832600: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8902
# 2023-06-28 13:53:27.097992: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-06-28 13:53:29.243385: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Model1 - Fold1Accuracy: 0.9998848580517462
# Model1 - Fold1Jaccard: 0.8151654444228539
# Model1 - Fold1Dice: 0.8903820836232543
# Model1 - Fold1F1-Score: 0.8903820836232543
# Model1 - Fold1Precision: 0.8195083062271056
# Model1 - Fold1Recall: 0.9904422180934794
# Model2 - Fold1Accuracy: 0.9998852495361911
# Model2 - Fold1Jaccard: 0.8090100660561906
# Model2 - Fold1Dice: 0.885617547874437
# Model2 - Fold1F1-Score: 0.885617547874437
# Model2 - Fold1Precision: 0.8105266098574897
# Model2 - Fold1Recall: 0.9940183375991689
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model1 - Fold2Accuracy: 0.9999232326316378
# Model1 - Fold2Jaccard: 0.8425953020073149
# Model1 - Fold2Dice: 0.9029589844336328
# Model1 - Fold2F1-Score: 0.9029589844336328
# Model1 - Fold2Precision: 0.8622323512863309
# Model1 - Fold2Recall: 0.9676950371627244
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model2 - Fold2Accuracy: 0.9999368526486053
# Model2 - Fold2Jaccard: 0.8617088868548518
# Model2 - Fold2Dice: 0.9199178791004875
# Model2 - Fold2F1-Score: 0.9199178791004875
# Model2 - Fold2Precision: 0.8816662309410954
# Model2 - Fold2Recall: 0.9741333410612972
# Model1 - Fold3Accuracy: 0.9999148566853744
# Model1 - Fold3Jaccard: 0.8352450039568388
# Model1 - Fold3Dice: 0.9061346033192076
# Model1 - Fold3F1-Score: 0.9061346033192076
# Model1 - Fold3Precision: 0.8396563185252715
# Model1 - Fold3Recall: 0.9942903336000436
# Model2 - Fold3Accuracy: 0.9999267195744844
# Model2 - Fold3Jaccard: 0.8526693650304136
# Model2 - Fold3Dice: 0.9162524080134028
# Model2 - Fold3F1-Score: 0.9162524080134028
# Model2 - Fold3Precision: 0.853705698905012
# Model2 - Fold3Recall: 0.9988545837228572
# Model1 - Fold4Accuracy: 0.9999218943010936
# Model1 - Fold4Jaccard: 0.8675779537293358
# Model1 - Fold4Dice: 0.9262905075989447
# Model1 - Fold4F1-Score: 0.9262905075989447
# Model1 - Fold4Precision: 0.8716394944923108
# Model1 - Fold4Recall: 0.9942020111140503
# Model2 - Fold4Accuracy: 0.9999346767234347
# Model2 - Fold4Jaccard: 0.867740208370496
# Model2 - Fold4Dice: 0.9252074784701007
# Model2 - Fold4F1-Score: 0.9252074784701007
# Model2 - Fold4Precision: 0.8683190346995494
# Model2 - Fold4Recall: 0.9992393272983966
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model1 - Fold5Accuracy: 0.9998998072949685
# Model1 - Fold5Jaccard: 0.8252576653793859
# Model1 - Fold5Dice: 0.8959350128711532
# Model1 - Fold5F1-Score: 0.8959350128711532
# Model1 - Fold5Precision: 0.8354633239778062
# Model1 - Fold5Recall: 0.9779882264039068
# Model2 - Fold5Accuracy: 0.9999190537627956
# Model2 - Fold5Jaccard: 0.8322488880541741
# Model2 - Fold5Dice: 0.9038574777709629
# Model2 - Fold5F1-Score: 0.9038574777709629
# Model2 - Fold5Precision: 0.8455076226557562
# Model2 - Fold5Recall: 0.9848985717019285

# %%
print("Accuracy: "+ str(np.mean(acc_mean_fold)*100) + " +- " + str(np.std(acc_std_fold)*100))
print("Jaccard: "+ str(np.mean(jacc_mean_fold)*100) + " +- " + str(np.std(jacc_std_fold)*100))
print("Dice: "+ str(np.mean(dice_mean_fold)*100) + " +- " + str(np.std(dice_std_fold)*100))
print("F1 Score: "+ str(np.mean(f1_mean_fold)*100) + " +- " + str(np.std(f1_std_fold)*100))
print("Precision: "+ str(np.mean(prec_mean_fold)*100) + " +- " + str(np.std(prec_std_fold)*100))
print("Recall: "+ str(np.mean(rec_mean_fold)*100) + " +- " + str(np.std(rec_std_fold)*100))
# Out:
# Accuracy: 99.99147201210332 +- 0.0034353610879576764
# Jaccard: 84.09218783861856 +- 2.113546012007693
# Dice: 90.72553983075584 +- 2.360876155364114
# F1 Score: 90.72553983075584 +- 2.360876155364114
# Precision: 84.88224991567728 +- 2.2431491166292794
# Recall: 98.75761987757852 +- 3.2608608274613484

# %%
dice_mean_fold
# Out:
# [0.8903820836232543,
#  0.885617547874437,
#  0.9029589844336328,
#  0.9199178791004875,
#  0.9061346033192076,
#  0.9162524080134028,
#  0.9262905075989447,
#  0.9252074784701007,
#  0.8959350128711532,
#  0.9038574777709629]

# %%
best_model = tf.keras.models.load_model('UNET 5x2-fold models/model1_4fold.h5')
# Out:
# 2023-09-15 16:38:34.435501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:34.629675: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:34.629761: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:34.630925: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-15 16:38:34.632233: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:34.632299: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:34.632329: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:35.557336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:35.557855: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:35.557870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1700] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-09-15 16:38:35.557910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:966] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-09-15 16:38:35.557928: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-09-15 16:38:35.557934: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2023-09-15 16:38:35.558093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9394 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=split_size, random_state=seeds[3])

# %%
def display(display_list):
  plt.figure(figsize=(15, 15))

  title = ['Input image', 'True mask', 'Predicted mask']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.utils.array_to_img(display_list[i]), cmap='gray')
    plt.axis('off')
  plt.show()
  
i = random.randint(0, len(X_val))
sample_image = X_val[i]
sample_mask = y_val[i]
prediction = best_model.predict(sample_image[tf.newaxis, ...])[0]
predicted_mask = (prediction > 0.5).astype(np.uint8)
display([sample_image, sample_mask,predicted_mask])

sample_mask = y_val[i].astype(np.uint8).flatten()
predicted_mask = predicted_mask.flatten()


print("Accuracy: "+ str(accuracy_score(sample_mask, predicted_mask)))
print("Jaccard: "+ str(jaccard_score(sample_mask, predicted_mask)))
print("Dice: "+ str((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask))))
print("Precision: "+ str(precision_score(sample_mask, predicted_mask)))
print("Recall: "+ str(recall_score(sample_mask, predicted_mask)))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Accuracy: 0.999786376953125
# Jaccard: 0.8564102564102564
# Dice: 0.9226519337016573
# Precision: 0.8608247422680413
# Recall: 0.9940476190476191

# %%
img = imread('normal/image/normal2.jpg', as_gray=True)[:,:]
img = img.reshape(img.shape[0], img.shape[1], IMG_CHANNELS)
img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)

mask = imread('normal/label/2.png', as_gray=True)
mask = (mask != 0)
mask = np.expand_dims(resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                  preserve_range=True), axis=-1)
sample_image = img
sample_mask = mask
prediction = best_model.predict(sample_image[tf.newaxis, ...])[0]
predicted_mask = (prediction > 0.5).astype(np.uint8)
display([sample_image, sample_mask,predicted_mask])

sample_mask = mask.astype(np.uint8).flatten()
predicted_mask = predicted_mask.flatten()


print("Accuracy: "+ str(accuracy_score(sample_mask, predicted_mask)))
print("Jaccard: "+ str(jaccard_score(sample_mask, predicted_mask)))
print("Dice: "+ str((2*jaccard_score(sample_mask, predicted_mask))/(1+jaccard_score(sample_mask, predicted_mask))))
print("Precision: "+ str(precision_score(sample_mask, predicted_mask)))
print("Recall: "+ str(recall_score(sample_mask, predicted_mask)))
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Accuracy: 1.0
# Jaccard: 0.0
# Dice: 0.0
# Precision: 0.0
# Recall: 0.0
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mbouzon/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
